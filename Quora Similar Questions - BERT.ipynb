# %%
import pandas as pd
import numpy as np
import re

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import euclidean_distances

# %%
from sentence_transformers import SentenceTransformer

# %%
from nltk.corpus import stopwords

# %%
questions_df = pd.read_csv("./QuoraQuestions.csv")
# taken from https://www.kaggle.com/c/quora-question-pairs

# %%
questions_df.head()
# Out:
#                                             question
# 0  What is the step by step guide to invest in sh...
# 1  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2  How can I increase the speed of my internet co...
# 3  Why am I mentally very lonely? How can I solve...
# 4  Which one dissolve in water quikly sugar, salt...

# %%
questions_df.shape
# Out:
# (404290, 1)

# %%
questions_df = questions_df.drop_duplicates()

# %%
# removing stop words from the text
stop_words_l=stopwords.words('english')

# %%
questions_df['question_cleaned'] = \
questions_df.question.apply(lambda x: " ".\
                             join(re.sub(r'[^a-zA-Z]',' ',w).lower() \
                                  for w in str(x).split() if re.sub(r'[^a-zA-Z]',' ',w).lower() not in stop_words_l))

# %%
questions_df['question_cleaned'] = questions_df['question_cleaned'].str.lower()

# %%
# to save time, samller set
questions_df = questions_df[:10000]

# %%
len(questions_df)
# Out:
# 10000

# %%
embedder = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
corpus_embeddings = embedder.encode(questions_df['question_cleaned'].tolist())

# %%
pairwise_similarities=cosine_similarity(corpus_embeddings)
pairwise_differences=euclidean_distances(corpus_embeddings)

# %%
pairwise_differences.shape
# Out:
# (10000, 10000)

# %%
pairwise_similarities.shape
# Out:
# (10000, 10000)

# %%
# Cosine Similarity for first document 
i = 1  # document serial number  in corpus
print (f'Document: {questions_df.iloc[i]["question"]}')
print ('\n')
print (f'Similar Documents using Cosine Similarity:')
similar_ix=np.argsort(pairwise_similarities[i])[::-1]
for ix in similar_ix:
        if ix==i:
            continue
        print('\n')
        print (f'Document: {questions_df.iloc[ix]["question"]}')
        print (f'Cosine Similarity : {pairwise_similarities[i][ix]}')
# Out:
# Document: What is the story of Kohinoor (Koh-i-Noor) Diamond?
#
#
# Similar Documents using Cosine Similarity:
#
#
# Document: How do I Import diamonds from India?
# Cosine Similarity : 0.6956050395965576
#
#
# Document: What is this triple talaq issue all about?
# Cosine Similarity : 0.671298623085022
#
#
# Document: A title for my continuation to The Gift of the Magi?
# Cosine Similarity : 0.6617215871810913
#
#
# Document: What prompted Wheel of Fortune to use the letters R S T L N and E in the bonus round?
# Cosine Similarity : 0.6543921828269958
#
#
# Document: What do you think about the Bajaj Dominar 400?
# Cosine Similarity : 0.646632194519043
#
#
# Document: Will Modi win in 2019?
# Cosine Similarity : 0.6458619236946106
#
#
# Document: What is going on between Hrithik roshan & Kangana Ranawat?
# Cosine Similarity : 0.6416058540344238
#
#
# Document: What does each line mean from the song STARBOY by Weeknd ?
# Cosine Similarity : 0.6415197849273682
#
#
# Document: Who was Koundinya Rishi?
# Cosine Similarity : 0.6364653706550598
#
#
# Document: Is Jamie Azor Ahai?
# Cosine Similarity : 0.632646918296814
#
#
# Document: Where is Nangli Wazidpur?
# Cosine Similarity : 0.6317147016525269
#
#
# Document: How do you tell a narcissist they are narcissist?
# Cosine Similarity : 0.6311607956886292
#
#
# Document: Is 1 to the power infinity =1?
# Cosine Similarity : 0.6284404993057251
#
#
# Document: Why is Manaphy so whiny?
# Cosine Similarity : 0.6282840967178345
#
#
# Document: Why is sandeep maheshwari not on Quora?
# Cosine Similarity : 0.6230437755584717
#
#
# Document: Is infinity a number?
# Cosine Similarity : 0.6199163198471069
#
#
# Document: What are the diamond shaped structures in the middle of railway tracks?
# Cosine Similarity : 0.6178228855133057
#
#
# Document: Boon and bane of supplementary exams?
# Cosine Similarity : 0.6177821755409241
#
#
# Document: What is a Darth?
# Cosine Similarity : 0.6168981790542603
#
#
# Document: What should I do after a BTech in CSE?
# Cosine Similarity : 0.614826500415802
#
#
# Document: What is Quora, and what is the relevence?
# Cosine Similarity : 0.6130813956260681
#
#
# Document: What does magizhchi mean?
# Cosine Similarity : 0.6124362945556641
#
#
# Document: How can I tell if I’m a narcissist?
# Cosine Similarity : 0.6086164712905884
#
#
# Document: What happened to David dvdasa?
# Cosine Similarity : 0.6073402166366577
#
#
# Document: What is the best way to make a responsive grid of "diamond shapes"?
# Cosine Similarity : 0.6038306951522827
#
#
# Document: What is triloca.com?
# Cosine Similarity : 0.603097677230835
#
#
# Document: What is the symbol for coppertone stock?
# Cosine Similarity : 0.6027898788452148
#
#
# Document: The prime factorization of intezer N is A x A x B x C, where A, B and C are all distinct prine intezers. How many factors does N have?
# Cosine Similarity : 0.6027140617370605
#
#
# Document: Stphen william hawking?
# Cosine Similarity : 0.6022282242774963
#
#
# Document: What does the Quran say about triple talaq?
# Cosine Similarity : 0.6020035743713379
#
#
# Document: What should I do to become an RJ in Indore?
# Cosine Similarity : 0.6010549664497375
#
#
# Document: What does "Quora " mean?
# Cosine Similarity : 0.6003099679946899
#
#
# Document: What is the difference between INFJ-T and INFJ-A?
# Cosine Similarity : 0.5983374714851379
#
#
# Document: How much does Kapil Sharma charge for a show?
# Cosine Similarity : 0.5971934795379639
#
#
# Document: What does the exclamation point mean in excel?
# Cosine Similarity : 0.5965982675552368
#
#
# Document: What should you engrave on promise rings?
# Cosine Similarity : 0.5953831076622009
#
#
# Document: Why is The Count of Monte Cristo so long?
# Cosine Similarity : 0.5952980518341064
#
#
# Document: What is cerber 3?
# Cosine Similarity : 0.5948199033737183
#
#
# Document: What doe Quora mean?
# Cosine Similarity : 0.5941819548606873
#
#
# Document: If I give IIM A B and C 5 stars each, how do you rate L I and K?
# Cosine Similarity : 0.5941445827484131
#
#
# Document: What is this CH3 and H3C?
# Cosine Similarity : 0.5938783884048462
#
#
# Document: Why are the Seven Wonders of the World referred to as Wonders?
# Cosine Similarity : 0.5930761098861694
#
#
# Document: How do I know if I'm a narcissist?
# Cosine Similarity : 0.5928655862808228
#
#
# Document: What are the effects of Shani sade sati?
# Cosine Similarity : 0.5922990441322327
#
#
# Document: What does "lien amount" in the SBI mean?
# Cosine Similarity : 0.590972900390625
#
#
# Document: What Anna Hazare think about PM Modi?
# Cosine Similarity : 0.5908738374710083
#
#
# Document: What's your secret to success?
# Cosine Similarity : 0.590819239616394
#
#
# Document: How do I root Micromax Canvas Knight Cameo?
# Cosine Similarity : 0.5905672907829285
#
#
# Document: What is illuminati? What does it do?
# Cosine Similarity : 0.5892218351364136
#
#
# Document: Why did harry become a horcrux?
# Cosine Similarity : 0.589185893535614
#
#
# Document: Is Illuminati a real theory?
# Cosine Similarity : 0.5884095430374146
#
#
# Document: Is Sadhguru a conman?
# Cosine Similarity : 0.5882081985473633
#
#
# Document: What is the effect of demonetization of 500 and 1000 rupees note?
# Cosine Similarity : 0.5862108469009399
#
#
# Document: What it is like to work in RBI?
# Cosine Similarity : 0.5855110883712769
#
#
# Document: What does NAFTA stand for?
# Cosine Similarity : 0.5855008363723755
#
#
# Document: Who owns Punreal.com?
# Cosine Similarity : 0.5852559804916382
#
#
# Document: What's your contribution to the world so far?
# Cosine Similarity : 0.5850642323493958
#
#
# Document: How do you wear a promise ring?
# Cosine Similarity : 0.5849788784980774
#
#
# Document: How can you tell if you are a narcissist?
# Cosine Similarity : 0.5844193696975708
#
#
# Document: Why is Jean Claude Van Damme not in The Expendables?
# Cosine Similarity : 0.584196925163269
#
#
# Document: What is the OBC cut off for IIFT 2015?
# Cosine Similarity : 0.5831249356269836
#
#
# Document: Who own ygeia3.com?
# Cosine Similarity : 0.5823350548744202
#
#
# Document: What is the meaning of the name Athira?
# Cosine Similarity : 0.5822538733482361
#
#
# Document: What exactly is a backend developer?
# Cosine Similarity : 0.5820116996765137
#
#
# Document: What is it like to be Jack Dorsey?
# Cosine Similarity : 0.5819488763809204
#
#
# Document: What is Jan lokapal bill?
# Cosine Similarity : 0.5813512802124023
#
#
# Document: Is declartion statement reuired in a resume?
# Cosine Similarity : 0.580191969871521
#
#
# Document: How can I solve arcsin (x^2) / x^2?
# Cosine Similarity : 0.5793552398681641
#
#
# Document: Why should I answer in Quora?
# Cosine Similarity : 0.579187273979187
#
#
# Document: How do I my epf account no I have my uan?
# Cosine Similarity : 0.5790557861328125
#
#
# Document: How far would you go for love? Should I wait for the one I love ir move on?
# Cosine Similarity : 0.5787663459777832
#
#
# Document: Who is blasie pascal?
# Cosine Similarity : 0.5786739587783813
#
#
# Document: How do you say 1<x<2?
# Cosine Similarity : 0.5786571502685547
#
#
# Document: What do you think of Shifuji Shaurya Bhardwaj?
# Cosine Similarity : 0.5785658955574036
#
#
# Document: What are some of the truths about life in DU?
# Cosine Similarity : 0.5781995058059692
#
#
# Document: Why has the RBI launched the 1000 rupee coin? What is the significance of it?
# Cosine Similarity : 0.5776896476745605
#
#
# Document: I'm 18. What should I do?
# Cosine Similarity : 0.5772327780723572
#
#
# Document: Who according to you is a hero? Why?
# Cosine Similarity : 0.5770341753959656
#
#
# Document: How do you put notes in a TI-84 Plus?
# Cosine Similarity : 0.5768004059791565
#
#
# Document: How is imagery used in "David" by Earle Birney?
# Cosine Similarity : 0.5765892863273621
#
#
# Document: How would an arbitrageur seek to capitalize given the following conditions: S0 + Pa (S0,T,X) < Ca (S0,T,X) + X (l + r) ^(-T)?
# Cosine Similarity : 0.5761841535568237
#
#
# Document: What is the best way to counter Meepo in Dota 2?
# Cosine Similarity : 0.5761606097221375
#
#
# Document: How hard is the AWS Developer Associate certification?
# Cosine Similarity : 0.5754994750022888
#
#
# Document: How do I get addmision in MIT?
# Cosine Similarity : 0.5753728747367859
#
#
# Document: What can one million dollars do?
# Cosine Similarity : 0.5752338171005249
#
#
# Document: Who is Redd Foxx?
# Cosine Similarity : 0.5749276280403137
#
#
# Document: For BITSAT & IIT JEE Mains 'theory', is NCERT sufficient?
# Cosine Similarity : 0.5745612382888794
#
#
# Document: How was the KVPY 2016 sa?
# Cosine Similarity : 0.5744048357009888
#
#
# Document: How was your KVPY sa 2016?
# Cosine Similarity : 0.5744048357009888
#
#
# Document: Why does noone see the diference between Endless and Infinite?
# Cosine Similarity : 0.5741649866104126
#
#
# Document: Which DLP is the best for the JEE?
# Cosine Similarity : 0.5741360187530518
#
#
# Document: What is the IIT, Roorkee cutoff for instrumentation?
# Cosine Similarity : 0.5739778280258179
#
#
# Document: What happens when you combine H2O and CO2?
# Cosine Similarity : 0.573914647102356
#
#
# Document: What is sensex? What is nifty?
# Cosine Similarity : 0.5733568072319031
#
#
# Document: What are 5 facts about the earth's crust?
# Cosine Similarity : 0.5730925798416138
#
#
# Document: How long does it take to get an offer?
# Cosine Similarity : 0.5730739235877991
#
#
# Document: What is the chord progression in Underworld's "8 Ball"?
# Cosine Similarity : 0.5727599859237671
#
#
# Document: What are the Keys to the Kingdom?
# Cosine Similarity : 0.5724184513092041
#
#
# Document: Waht is diploid?
# Cosine Similarity : 0.5721694827079773
#
#
# Document: What's the placement scenario for an MTech in Instrumentation at NIT Agartala?
# Cosine Similarity : 0.5716397762298584
#
#
# Document: What is difference between immortality and eternity?
# Cosine Similarity : 0.5711381435394287
#
#
# Document: Is incognitovpn.com legit?
# Cosine Similarity : 0.5711138248443604
#
#
# Document: Where can I find Kapoor and sons torrent?
# Cosine Similarity : 0.5708032250404358
#
#
# Document: How do I get off Quora?
# Cosine Similarity : 0.5706924200057983
#
#
# Document: Why can I upvote this Quora question?
# Cosine Similarity : 0.5695925951004028
#
#
# Document: How are YIF placements?
# Cosine Similarity : 0.5690668225288391
#
#
# Document: What is the most viewed answer you have got on Quora?
# Cosine Similarity : 0.5688854455947876
#
#
# Document: What was it like to work with Satya Nadella?
# Cosine Similarity : 0.5685837268829346
#
#
# Document: What is the main role of I?
# Cosine Similarity : 0.5681905150413513
#
#
# Document: Where can I get the Jacket that Ranbir Kapoor is wearing in song 'Matargashti'?
# Cosine Similarity : 0.5678874254226685
#
#
# Document: How is FIITJEE Delhi?
# Cosine Similarity : 0.5678668022155762
#
#
# Document: Are there other equivalents of the Wights in ASOIAF?
# Cosine Similarity : 0.5677598714828491
#
#
# Document: Is there one god or many?
# Cosine Similarity : 0.5675132870674133
#
#
# Document: Why are most Quora answers so long?
# Cosine Similarity : 0.5669299364089966
#
#
# Document: Is our PM Modi doing the correct thing with 500 and 1000 Rs notes?
# Cosine Similarity : 0.5666337013244629
#
#
# Document: What is the cutoff percentile for NITIE and MDI Gurgaon this year?
# Cosine Similarity : 0.5665480494499207
#
#
# Document: What's the meaning of the "Triune God"?
# Cosine Similarity : 0.5664041042327881
#
#
# Document: Who backs the insurance for Metromile?
# Cosine Similarity : 0.5655065774917603
#
#
# Document: What is the power of a dream?
# Cosine Similarity : 0.5649234652519226
#
#
# Document: What is the IELTS all about?
# Cosine Similarity : 0.5643041133880615
#
#
# Document: What is the difference between Worldpay and Stripe?
# Cosine Similarity : 0.5642282962799072
#
#
# Document: What are some lesser known facts about Taarak Mehta Ka Ooltah Chashmah?
# Cosine Similarity : 0.564213216304779
#
#
# Document: What is the difference between zamindari, ryotwari and mahalwari system?
# Cosine Similarity : 0.5641113519668579
#
#
# Document: What individuals and events in history are a source of pride for São Tomé and Príncipe?
# Cosine Similarity : 0.5636792182922363
#
#
# Document: What is the significance of a 1962 American nickel?
# Cosine Similarity : 0.5634325742721558
#
#
# Document: What is Omoto.io?
# Cosine Similarity : 0.5633742809295654
#
#
# Document: How is Dabba trading done?
# Cosine Similarity : 0.5629576444625854
#
#
# Document: Could the RPK be belt-fed?
# Cosine Similarity : 0.5624900460243225
#
#
# Document: What does a double triangle tattoo mean?
# Cosine Similarity : 0.5623397827148438
#
#
# Document: What is the difference between BPEL, BPMN and BPM?
# Cosine Similarity : 0.5622013807296753
#
#
# Document: Who is Sai Rahul Paluvai? And why is he a legend?
# Cosine Similarity : 0.5616602301597595
#
#
# Document: What is the biggest lie you have ever told on Quora?
# Cosine Similarity : 0.561421811580658
#
#
# Document: What does tw4t mean?
# Cosine Similarity : 0.5613393783569336
#
#
# Document: What is the Tumblr story?
# Cosine Similarity : 0.5613299012184143
#
#
# Document: What is Jeffrey Kearns' opinion on Khan Academy?
# Cosine Similarity : 0.5612432360649109
#
#
# Document: What is the "Anaar ke chilke ka totka " of GD Vasistha for debt returning?
# Cosine Similarity : 0.5607804656028748
#
#
# Document: How can I get job in Accenture?
# Cosine Similarity : 0.5605772733688354
#
#
# Document: What's the difference between IT and COE at NSIT and DTU?
# Cosine Similarity : 0.5597307682037354
#
#
# Document: What is the meaning of the name Manishaa?
# Cosine Similarity : 0.559501051902771
#
#
# Document: What is the relationship between E(1/x) and 1/E(x)?
# Cosine Similarity : 0.5591817498207092
#
#
# Document: What words rhyme with "saying"?
# Cosine Similarity : 0.5584087371826172
#
#
# Document: What is the limit of cos^2(1/(x^2)) as x->0?
# Cosine Similarity : 0.5583505630493164
#
#
# Document: How do delete Quora quesitons?
# Cosine Similarity : 0.5580847263336182
#
#
# Document: How is the word 'valiant' used in a sentence?
# Cosine Similarity : 0.5580462217330933
#
#
# Document: What is the meaning of para and gravida?
# Cosine Similarity : 0.5579666495323181
#
#
# Document: How is Physics Galaxy by Ashish Arora? Is it relevant for JEE?
# Cosine Similarity : 0.5578960180282593
#
#
# Document: How TQWL is different from CKWL (Tatkal waiting list)?
# Cosine Similarity : 0.5566719174385071
#
#
# Document: Is Oculus done?
# Cosine Similarity : 0.5564150810241699
#
#
# Document: Which is best ejabberd or openfire?
# Cosine Similarity : 0.5563070178031921
#
#
# Document: What does my kundali reveal about my career?
# Cosine Similarity : 0.5559537410736084
#
#
# Document: What is my GPA if I have scored 65% in my 11th std CBSE?
# Cosine Similarity : 0.5559158325195312
#
#
# Document: How is the movie MS Dhoni untold story?
# Cosine Similarity : 0.5547236204147339
#
#
# Document: Who do you think will win IPL 2015?
# Cosine Similarity : 0.5544673204421997
#
#
# Document: What are some of the biggest blunders in history?
# Cosine Similarity : 0.5540406703948975
#
#
# Document: What's harder at Stanford: CS 246 or 229?
# Cosine Similarity : 0.5535435676574707
#
#
# Document: How do I registered my moblie number for my aadhar card?
# Cosine Similarity : 0.5534515380859375
#
#
# Document: How can I be the top 1% of the world?
# Cosine Similarity : 0.5533294677734375
#
#
# Document: How can I prove that (A × B) − (C × D) = (A − C) × B ∪ A × (B − D)?
# Cosine Similarity : 0.5531191825866699
#
#
# Document: When was Quora launched?
# Cosine Similarity : 0.552703320980072
#
#
# Document: What is your review of Crystal IT?
# Cosine Similarity : 0.5526519417762756
#
#
# Document: What was it like to work with Alan Greenspan?
# Cosine Similarity : 0.5523645281791687
#
#
# Document: What is Vyvanse used for?
# Cosine Similarity : 0.5521748661994934
#
#
# Document: How is the procentual difference between 4% and 3%?
# Cosine Similarity : 0.5520771741867065
#
#
# Document: How can I meet Suresh Raina?
# Cosine Similarity : 0.551834225654602
#
#
# Document: When will Pokémon GO release in India?
# Cosine Similarity : 0.5516425371170044
#
#
# Document: What year did the letter J come?
# Cosine Similarity : 0.551607072353363
#
#
# Document: Why do people belive in god?
# Cosine Similarity : 0.5513455271720886
#
#
# Document: What are the specifications of the Acer Aspire E14?
# Cosine Similarity : 0.5513266324996948
#
#
# Document: How can I hack Clash of Clans for unlimited gems?
# Cosine Similarity : 0.5507621765136719
#
#
# Document: Why is it taking so long for Pokémon GO to be available in India?
# Cosine Similarity : 0.5505120158195496
#
#
# Document: What is the one thing that you would like to do if you had an unlimited amount of money?
# Cosine Similarity : 0.55036860704422
#
#
# Document: What is journalism for you?
# Cosine Similarity : 0.5501627922058105
#
#
# Document: Why is Kim Jung-Un so fat?
# Cosine Similarity : 0.5501267910003662
#
#
# Document: What's the difference between mi5 a?
# Cosine Similarity : 0.5497336387634277
#
#
# Document: Can I use IRCTC eWallet for Tatkal Booking?
# Cosine Similarity : 0.549579918384552
#
#
# Document: Is VNIT tier 1 college?
# Cosine Similarity : 0.5493179559707642
#
#
# Document: What is the expected neet 2 cutoff?
# Cosine Similarity : 0.5492578744888306
#
#
# Document: What's the meaning of euthenesia?
# Cosine Similarity : 0.5491457581520081
#
#
# Document: Who is the PM of India?
# Cosine Similarity : 0.5488288998603821
#
#
# Document: What are the differences between WeChat and QQ?
# Cosine Similarity : 0.5487409234046936
#
#
# Document: What do the grade shares mean?
# Cosine Similarity : 0.5486167073249817
#
#
# Document: What are the major differences betweeen SAP HANA and SAP R/3?
# Cosine Similarity : 0.5482978820800781
#
#
# Document: How do I research for MUN?
# Cosine Similarity : 0.5478476881980896
#
#
# Document: What are some iconic quotes about Rahul Dravid?
# Cosine Similarity : 0.547665536403656
#
#
# Document: What is the all-time most viewed question on Quora?
# Cosine Similarity : 0.5475930571556091
#
#
# Document: How much is 30 kV in HP?
# Cosine Similarity : 0.5475929975509644
#
#
# Document: Is Stevie Wonder married?
# Cosine Similarity : 0.5471609830856323
#
#
# Document: Why do you think you are special?
# Cosine Similarity : 0.5466955900192261
#
#
# Document: What happened to Tmartn?
# Cosine Similarity : 0.5465111136436462
#
#
# Document: How do I get bokeh effect on 50mm f1.8 when the sweet spot is f5.6?
# Cosine Similarity : 0.5464490056037903
#
#
# Document: Why does San Marino exist?
# Cosine Similarity : 0.5461887717247009
#
#
# Document: What is the Heisenberg uncertainty priciple?
# Cosine Similarity : 0.546023964881897
#
#
# Document: If w is brownian motion t is time, how dw^2=dt?
# Cosine Similarity : 0.545744776725769
#
#
# Document: Does Sheldon, Penny, Leonard and Howard know about the 'caste' of Rajesh Koothrapalli?
# Cosine Similarity : 0.5457005500793457
#
#
# Document: How do you know if you are in love with your crush?
# Cosine Similarity : 0.5454400181770325
#
#
# Document: What is a "quasi-contract"? What are some examples?
# Cosine Similarity : 0.5452490448951721
#
#
# Document: Is IMS noida good for BCA?
# Cosine Similarity : 0.545088529586792
#
#
# Document: What color was Adam and Eve?
# Cosine Similarity : 0.5450769066810608
#
#
# Document: Is God really present?
# Cosine Similarity : 0.5450674295425415
#
#
# Document: What were your experiences when you had roll no. 1?
# Cosine Similarity : 0.5449427366256714
#
#
# Document: What is the difference between final investigation report and jmfc 173 report?
# Cosine Similarity : 0.5448315739631653
#
#
# Document: What happened to ibeatyou.com?
# Cosine Similarity : 0.5447862148284912
#
#
# Document: When do you upvote?
# Cosine Similarity : 0.5445969700813293
#
#
# Document: How much is the maximum gold you can take when flying from India to USA?
# Cosine Similarity : 0.5444262623786926
#
#
# Document: What breed is Odie from the Garfield comics?
# Cosine Similarity : 0.5441522598266602
#
#
# Document: What is the scope of growth in the ITIS in TCS?
# Cosine Similarity : 0.543998122215271
#
#
# Document: How is Narendra Modi as a person?
# Cosine Similarity : 0.5439051389694214
#
#
# Document: Which are the famous caves in Chhattisgarh?
# Cosine Similarity : 0.543899655342102
#
#
# Document: What are examples of a pun?
# Cosine Similarity : 0.5438306331634521
#
#
# Document: What is the significance of Box 5 in Phantom of the Opera?
# Cosine Similarity : 0.5438094735145569
#
#
# Document: What are the major Development of Chhattisgarh?
# Cosine Similarity : 0.5436209440231323
#
#
# Document: What is rank at 550 marks in NEET 2016?
# Cosine Similarity : 0.5431573987007141
#
#
# Document: How is the word "jocund" used in a sentence?
# Cosine Similarity : 0.5430669188499451
#
#
# Document: What's the difference between 4G and 4G LTE?
# Cosine Similarity : 0.5430328249931335
#
#
# Document: What'd be the top (maximum) wavelength of an electromagnetic radiation to see a message written in a paper?
# Cosine Similarity : 0.5428441762924194
#
#
# Document: What was the significance of Severus Snape and Lily Potter having the same Patronus?
# Cosine Similarity : 0.5427942872047424
#
#
# Document: A no divisible by both 3 and 14?
# Cosine Similarity : 0.5427606105804443
#
#
# Document: How can I get free gems in Clash of Clans?
# Cosine Similarity : 0.542495846748352
#
#
# Document: Why is Timbaland famous?
# Cosine Similarity : 0.5417168140411377
#
#
# Document: What does Adam D'Angelo think of Quora being addictive?
# Cosine Similarity : 0.5416989922523499
#
#
# Document: How can I just be myself?
# Cosine Similarity : 0.5415986180305481
#
#
# Document: Why does Ichigo have hollow powers?
# Cosine Similarity : 0.5413129925727844
#
#
# Document: What are the differences between CSE and IT/ISE?
# Cosine Similarity : 0.5412805676460266
#
#
# Document: What camera does Charles Trippy use?
# Cosine Similarity : 0.541075587272644
#
#
# Document: What would be next strike from PM Modi after Demonetisation?
# Cosine Similarity : 0.5409374237060547
#
#
# Document: How much time will spotify take to land in India?
# Cosine Similarity : 0.5408217906951904
#
#
# Document: What is difference between Modi and Hitler?
# Cosine Similarity : 0.5406587719917297
#
#
# Document: What's the point of the joke about the horse pitching in Age of Adaline?
# Cosine Similarity : 0.5406457781791687
#
#
# Document: What is the greatest number that will divide 43, 91 and 183 so as to leave the same remainder in each case?
# Cosine Similarity : 0.5405818223953247
#
#
# Document: Why is there no option to +1 Quora posts?
# Cosine Similarity : 0.5399148464202881
#
#
# Document: Have you ever been fired?
# Cosine Similarity : 0.5397428274154663
#
#
# Document: How do I earn from Quora?
# Cosine Similarity : 0.5396767258644104
#
#
# Document: Can I earn from Quora?
# Cosine Similarity : 0.5396767258644104
#
#
# Document: What are Elizabeth Warren's positions?
# Cosine Similarity : 0.539497435092926
#
#
# Document: Is planet 9 real or a hype/joke like Nibiru?
# Cosine Similarity : 0.5394302606582642
#
#
# Document: Do I exist?
# Cosine Similarity : 0.5392757654190063
#
#
# Document: What is the difference between Type A and Type B NFC?
# Cosine Similarity : 0.5392539501190186
#
#
# Document: How does one fall in love?
# Cosine Similarity : 0.5392162799835205
#
#
# Document: Is it possible to do CA after 12th Science?
# Cosine Similarity : 0.5391095876693726
#
#
# Document: What is the real meaning of the Indian flag Tiranga?
# Cosine Similarity : 0.5387517213821411
#
#
# Document: What is the difference between lard and suet?
# Cosine Similarity : 0.5387256741523743
#
#
# Document: Would you switch from Canon 6D to Leica D-LUX 109?
# Cosine Similarity : 0.5383110046386719
#
#
# Document: What is the Mahabharata and Ramyana about?
# Cosine Similarity : 0.5383082032203674
#
#
# Document: How do you know you have a crush?
# Cosine Similarity : 0.5380303263664246
#
#
# Document: Which country has highest gold reserves?
# Cosine Similarity : 0.5375207662582397
#
#
# Document: What is the difference between O- and O+?
# Cosine Similarity : 0.537510097026825
#
#
# Document: Human Behavior: What is the one lie that you tell yourself repeatedly?
# Cosine Similarity : 0.5373000502586365
#
#
# Document: What is meant by "the language of a story"?
# Cosine Similarity : 0.5372072458267212
#
#
# Document: What's a cornerstone investor?
# Cosine Similarity : 0.5371975898742676
#
#
# Document: National Anthems: Do anyone know from which novel Jana Gana Mana is taken?
# Cosine Similarity : 0.5368213653564453
#
#
# Document: What is activated complex?
# Cosine Similarity : 0.5367808938026428
#
#
# Document: How do I convert NRE FD to RFC?
# Cosine Similarity : 0.5367478728294373
#
#
# Document: Does freedom of speech extend to shouting?
# Cosine Similarity : 0.5360934138298035
#
#
# Document: What are the greatest comebacks in history?
# Cosine Similarity : 0.5354595184326172
#
#
# Document: IN WHAT Time will rs 3000 amounts to rs 5184 at compounded interest of 20%?
# Cosine Similarity : 0.5353453755378723
#
#
# Document: Why do I love her so much?
# Cosine Similarity : 0.5351406335830688
#
#
# Document: Is suzlon energy worth accumulating at this levels 17-18?
# Cosine Similarity : 0.535035252571106
#
#
# Document: If you were guaranteed the answer to one question, what would it be?
# Cosine Similarity : 0.5348905920982361
#
#
# Document: Will mhtcet engineering happen in 2017?
# Cosine Similarity : 0.5348779559135437
#
#
# Document: What is the best way to round to the nearest integer?
# Cosine Similarity : 0.5346499681472778
#
#
# Document: Does Moto g4 plus heat?
# Cosine Similarity : 0.5345565676689148
#
#
# Document: What exactly are in-phase and out-of-phase in terms of waves?
# Cosine Similarity : 0.534365177154541
#
#
# Document: Is Envita.com legit?
# Cosine Similarity : 0.5343065857887268
#
#
# Document: Which one is correct? “please let me know if you have any question” or ”please let me know if you have any questions”
# Cosine Similarity : 0.5341135859489441
#
#
# Document: Are Pixotine coupon Codes available?
# Cosine Similarity : 0.5338741540908813
#
#
# Document: What is the meaning of Urdu word 'Nasaaz'?
# Cosine Similarity : 0.5338492393493652
#
#
# Document: What is Kaufmich.com?
# Cosine Similarity : 0.5338128209114075
#
#
# Document: Between Robert De Niro and Al Pacino, who is more successful?
# Cosine Similarity : 0.5337917804718018
#
#
# Document: How do I deal with a love triangle?
# Cosine Similarity : 0.5337098240852356
#
#
# Document: Have you used Quora to find love?
# Cosine Similarity : 0.533696711063385
#
#
# Document: Why is my period 11 days late and how probable is it that I'm pregnant?
# Cosine Similarity : 0.5336804389953613
#
#
# Document: Is premarital sex ok?
# Cosine Similarity : 0.5336558818817139
#
#
# Document: What is it like to work at Prettysecrets.com?
# Cosine Similarity : 0.5333977937698364
#
#
# Document: What is the greatest mystery of all time?
# Cosine Similarity : 0.5333139896392822
#
#
# Document: How does one move from the UK to the US?
# Cosine Similarity : 0.533312976360321
#
#
# Document: What is the most probable cutoff of KVPY SA 2016?
# Cosine Similarity : 0.5332378149032593
#
#
# Document: What is the difference between salary structure of RRB scale 1 and IBPS PO?
# Cosine Similarity : 0.5332281589508057
#
#
# Document: Is there any proof which can be given for the existence of the GOD? If yes, what are those?
# Cosine Similarity : 0.5332270264625549
#
#
# Document: Tinder - how do I delete my interests?
# Cosine Similarity : 0.5329138040542603
#
#
# Document: Why do I have to join CEPT?
# Cosine Similarity : 0.5325753092765808
#
#
# Document: Is the soul immortal?
# Cosine Similarity : 0.5323494672775269
#
#
# Document: What is the greatest mystery in the universe?
# Cosine Similarity : 0.5322195291519165
#
#
# Document: How would you make 1 million dollars into 10 million dollars?
# Cosine Similarity : 0.5321589112281799
#
#
# Document: What is the difference between cetirizine and levocetirizine?
# Cosine Similarity : 0.5320508480072021
#
#
# Document: How do you feel when someone upvotes your answer on Quora?
# Cosine Similarity : 0.5319942831993103
#
#
# Document: How can one increase concentration?
# Cosine Similarity : 0.5318844318389893
#
#
# Document: What's the 'Theory Of Everything' you believe in?
# Cosine Similarity : 0.5318640470504761
#
#
# Document: Want to know about Payoda (s/w company)?
# Cosine Similarity : 0.531860888004303
#
#
# Document: Who invented light years?
# Cosine Similarity : 0.531813383102417
#
#
# Document: How do Uber and Lyft compare in 2016?
# Cosine Similarity : 0.5315905809402466
#
#
# Document: Which 2G Band (900/1800Mhz) was sold during 2G spectrum scam?
# Cosine Similarity : 0.531470000743866
#
#
# Document: What is e-construction?
# Cosine Similarity : 0.5311791300773621
#
#
# Document: How do you know you are ready to tell your significant other you love them?
# Cosine Similarity : 0.530936598777771
#
#
# Document: In the play "A Raisin in the Sun", why do Walter ad Beneatha argue?
# Cosine Similarity : 0.5306446552276611
#
#
# Document: What is most embrassing moment of your life?
# Cosine Similarity : 0.5305526256561279
#
#
# Document: What does the nuclear membrane do?
# Cosine Similarity : 0.5304454565048218
#
#
# Document: What is the GST?
# Cosine Similarity : 0.5301929712295532
#
#
# Document: What is the Hizmet movement?
# Cosine Similarity : 0.5296850800514221
#
#
# Document: Is Zee news a BJP owned channel?
# Cosine Similarity : 0.529599130153656
#
#
# Document: What do you get when you rearrange the letters LNGEDNA?
# Cosine Similarity : 0.5295813083648682
#
#
# Document: What should I do to become a top writer on Quora?
# Cosine Similarity : 0.5295138359069824
#
#
# Document: How do I set up my VPN?
# Cosine Similarity : 0.5293161869049072
#
#
# Document: How do I tackle AIIMS or neet physics?
# Cosine Similarity : 0.5293075442314148
#
#
# Document: Can I get my provisional degree from MDU, Rohtak the same day? How much time does it take?
# Cosine Similarity : 0.5292419195175171
#
#
# Document: How do I root an HTC Desire 826?
# Cosine Similarity : 0.5289936065673828
#
#
# Document: Can you edit an answer on Quora?
# Cosine Similarity : 0.5287516117095947
#
#
# Document: CDSE 2016 merit list is already out. Is there a chance for TES 36 merit to come out in just few days?
# Cosine Similarity : 0.5283629894256592
#
#
# Document: What is the best ux resume?
# Cosine Similarity : 0.5283360481262207
#
#
# Document: Given that alpha and beta are roots of the equation 3x^2-5=0 form the equation whose roots are 2alpha-1/beta, 2alpha-/alpha?
# Cosine Similarity : 0.5282473564147949
#
#
# Document: What is a loop?
# Cosine Similarity : 0.5279684662818909
#
#
# Document: Cochin to London etihad is the change over time of 1hr sufficient in Dubai?
# Cosine Similarity : 0.5279202461242676
#
#
# Document: Why would you use "if __name__ == '__main__'"?
# Cosine Similarity : 0.5278840065002441
#
#
# Document: Will the novel ever die?
# Cosine Similarity : 0.5278835892677307
#
#
# Document: Should India change its name to Bharat/Hindustan?
# Cosine Similarity : 0.5277643799781799
#
#
# Document: How do I read the ammeter of an Enfield?
# Cosine Similarity : 0.5274356603622437
#
#
# Document: How can I convert Right Ascension and declination of a galaxy to distances in parsecs or any other common form?
# Cosine Similarity : 0.5273716449737549
#
#
# Document: What's the difference between LR6 and AA batteries?
# Cosine Similarity : 0.5273646712303162
#
#
# Document: How can one earn money on Quora?
# Cosine Similarity : 0.5268737077713013
#
#
# Document: What is your take on Urjit Patel as the new RBI governor?
# Cosine Similarity : 0.5268449187278748
#
#
# Document: Can I do 2 diplomas simultaneously?
# Cosine Similarity : 0.526729166507721
#
#
# Document: What will the real estate look like now after the 500 and 1000 scraping?
# Cosine Similarity : 0.5266517996788025
#
#
# Document: Was Adolf Hitler a patriot?
# Cosine Similarity : 0.5266036987304688
#
#
# Document: What do you think the cutoff of KVPY 2016 SA would be?
# Cosine Similarity : 0.5264933109283447
#
#
# Document: How do I add images in Quora?
# Cosine Similarity : 0.5264845490455627
#
#
# Document: What is the evidence of King David's existence?
# Cosine Similarity : 0.5264483690261841
#
#
# Document: Where is travencore state in India?
# Cosine Similarity : 0.5258238315582275
#
#
# Document: What is the value of a 2 rupee note signed by Sri Venkitaramanan (1990-1992)?
# Cosine Similarity : 0.5258034467697144
#
#
# Document: What is your review of The Motley Fool?
# Cosine Similarity : 0.5256295800209045
#
#
# Document: What is the definition of notorious service?
# Cosine Similarity : 0.5256047248840332
#
#
# Document: How did Leatherface (2017 movie) get greenlit? What's the backstory of how the movie got made?
# Cosine Similarity : 0.5253125429153442
#
#
# Document: What is the definition of "actual yield"?
# Cosine Similarity : 0.5247992277145386
#
#
# Document: What is a "Time Well" in physics?
# Cosine Similarity : 0.5247126817703247
#
#
# Document: In comics Tony is one of the few who welds the infinity gauntlet should we expect him to do something like that in future infinity wars movie?
# Cosine Similarity : 0.5246030688285828
#
#
# Document: What is the creamy layer and the non-creamy layer in the OBC category?
# Cosine Similarity : 0.5245288610458374
#
#
# Document: How you say lover in Hindi?
# Cosine Similarity : 0.5244755744934082
#
#
# Document: Definition of specific gravity?
# Cosine Similarity : 0.5243911743164062
#
#
# Document: How do I know if he is even a crush?
# Cosine Similarity : 0.5241075754165649
#
#
# Document: What does agape mean?
# Cosine Similarity : 0.5240992903709412
#
#
# Document: Is there anyone who had bhild their own algorithm?
# Cosine Similarity : 0.5240275859832764
#
#
# Document: When will episode 103 of fairy tail 2014 come out?
# Cosine Similarity : 0.5239077806472778
#
#
# Document: What should I do to prepare for NDA?
# Cosine Similarity : 0.5238111019134521
#
#
# Document: How hard was it for Jimmy Wales to immigrate to the UK?
# Cosine Similarity : 0.5237443447113037
#
#
# Document: What is the purpose of double pulsing a thyristor?
# Cosine Similarity : 0.5236225128173828
#
#
# Document: What is the relation between yudhishthira and Shakuni?
# Cosine Similarity : 0.5235529541969299
#
#
# Document: Why has not any Indian Mathematician won a Fields Medal?
# Cosine Similarity : 0.5234410762786865
#
#
# Document: Who is Bernard Dadie?
# Cosine Similarity : 0.5232471227645874
#
#
# Document: Does it matter where I do my masters?
# Cosine Similarity : 0.5232034921646118
#
#
# Document: What are the places yet to be discovered on Earth?
# Cosine Similarity : 0.5230627655982971
#
#
# Document: What was the last great decade for rock?
# Cosine Similarity : 0.5229970812797546
#
#
# Document: Is The Force Awakens the exact same plot as A New Hope?
# Cosine Similarity : 0.5229693651199341
#
#
# Document: What is the biggest scam in india now?
# Cosine Similarity : 0.5224778056144714
#
#
# Document: Does PGDIRA provides placements?
# Cosine Similarity : 0.5224382281303406
#
#
# Document: Did Mahabharata really happen?
# Cosine Similarity : 0.5223972797393799
#
#
# Document: If you had 100 billion dollars and you knew that you would always live like a multi-billionaire, what would be the first thing that you would do with that money?
# Cosine Similarity : 0.5223835110664368
#
#
# Document: Is Quora a hit or a miss?
# Cosine Similarity : 0.5221653580665588
#
#
# Document: What is a Crush Card in "Yu-Gi-Oh!"?
# Cosine Similarity : 0.5220563411712646
#
#
# Document: What does flimpist mean?
# Cosine Similarity : 0.5217244625091553
#
#
# Document: How do I check the price for HP Elitebook 8440P?
# Cosine Similarity : 0.5217195749282837
#
#
# Document: What is the difference between U and U/A certified films?
# Cosine Similarity : 0.521708607673645
#
#
# Document: What is one sided love for you?
# Cosine Similarity : 0.5216024518013
#
#
# Document: How do I make crack?
# Cosine Similarity : 0.5214183330535889
#
#
# Document: Is wowchat legal in India?
# Cosine Similarity : 0.521413266658783
#
#
# Document: How is L&T Technology Services IPO?
# Cosine Similarity : 0.5212147235870361
#
#
# Document: Are sakaldiwipi brahmins from Egypt?
# Cosine Similarity : 0.5210882425308228
#
#
# Document: How was quantum entanglement discovered?
# Cosine Similarity : 0.5210601687431335
#
#
# Document: I keep going back to the same place in my dream but the previous me is there already?
# Cosine Similarity : 0.5210434198379517
#
#
# Document: Why does Dushka Zapata have a story about EVERYTHING? Are they all true?
# Cosine Similarity : 0.5210345983505249
#
#
# Document: Which is the best mechanics book for the JEE Advanced - BM Sharma (Cengage), D.C. Pandey (Arihant) or Anurag Mishra (Balaji)?
# Cosine Similarity : 0.5208815336227417
#
#
# Document: What are the chances of ww3?
# Cosine Similarity : 0.5207166075706482
#
#
# Document: What are some gerunds examples?
# Cosine Similarity : 0.5207015872001648
#
#
# Document: Is there any way to recover registration number of ICAI?
# Cosine Similarity : 0.5206832885742188
#
#
# Document: What is Ali Garh Trusteeship bill?
# Cosine Similarity : 0.5206408500671387
#
#
# Document: Quora: How do you post a question on Quora?
# Cosine Similarity : 0.5206246972084045
#
#
# Document: Did Ben Affleck shine more than Christian Bale as Batman?
# Cosine Similarity : 0.520534098148346
#
#
# Document: What is SIN time?
# Cosine Similarity : 0.520523190498352
#
#
# Document: How does the rest of the world see Republicans?
# Cosine Similarity : 0.5203472375869751
#
#
# Document: How did you get into IIM?
# Cosine Similarity : 0.5202476978302002
#
#
# Document: Why is Arvind Kejriwal so obsessed with Modi?
# Cosine Similarity : 0.5201350450515747
#
#
# Document: What is Do's mission?
# Cosine Similarity : 0.5199507474899292
#
#
# Document: Do I need a domicile certificate for NEET?
# Cosine Similarity : 0.5199184417724609
#
#
# Document: What is the right name: Shawarma vs. Döner?
# Cosine Similarity : 0.5197215676307678
#
#
# Document: Could Snoke secretly be Darth Maul?
# Cosine Similarity : 0.519684910774231
#
#
# Document: What is coplanar force?
# Cosine Similarity : 0.5195481777191162
#
#
# Document: What is backend process?
# Cosine Similarity : 0.5195305347442627
#
#
# Document: Who owns this number 3152150252?
# Cosine Similarity : 0.5195156931877136
#
#
# Document: What is qiymat.com?
# Cosine Similarity : 0.5194488167762756
#
#
# Document: What would it look like here on earth if your sun was a Pulsar?
# Cosine Similarity : 0.5192453861236572
#
#
# Document: How do I get Pikachu as my first Pokémon in Pokémon GO?
# Cosine Similarity : 0.5191506147384644
#
#
# Document: What is the PAN number of the Punjab National Bank (PNB)?
# Cosine Similarity : 0.5188795328140259
#
#
# Document: What is the most interesting shell script you have ever written?
# Cosine Similarity : 0.5188678503036499
#
#
# Document: Why does Red keep the keys in OITNB?
# Cosine Similarity : 0.5187737941741943
#
#
# Document: Is someone born in 1977 generation X or Y?
# Cosine Similarity : 0.5187123417854309
#
#
# Document: Can a Lightsaber cut through Adamantium?
# Cosine Similarity : 0.5184422731399536
#
#
# Document: Why do I have a hard lump on my earlobe?
# Cosine Similarity : 0.5181844830513
#
#
# Document: How many zeros are in 1 million?
# Cosine Similarity : 0.5181771516799927
#
#
# Document: What is the Pixar logo, and what does it mean?
# Cosine Similarity : 0.518061637878418
#
#
# Document: Who is the most powerful character in Skyrim apart from Alduin?
# Cosine Similarity : 0.5180588960647583
#
#
# Document: What does Noam Chomsky think of communism?
# Cosine Similarity : 0.5179738998413086
#
#
# Document: Did stuff exist before the big bang, or not?
# Cosine Similarity : 0.5175930857658386
#
#
# Document: Why did ceaser give the other apes a cookie?
# Cosine Similarity : 0.5175048112869263
#
#
# Document: What should I double major with foreign language?
# Cosine Similarity : 0.517478883266449
#
#
# Document: What is the difference between Note 1 and 2?
# Cosine Similarity : 0.5173630714416504
#
#
# Document: What is that 80's song that has a chorus of "woah oh oh oh"?
# Cosine Similarity : 0.5173060297966003
#
#
# Document: Is hypnotism real? If yes, how does it work? Can you give a real life example?
# Cosine Similarity : 0.5172140598297119
#
#
# Document: Why should I crack Jee?
# Cosine Similarity : 0.517181932926178
#
#
# Document: How can I crack JEE?
# Cosine Similarity : 0.517181932926178
#
#
# Document: In layman's terms, what does Palantir actually do?
# Cosine Similarity : 0.5170037746429443
#
#
# Document: Is tattoo not allowed in IPS?
# Cosine Similarity : 0.5169224739074707
#
#
# Document: What should I know to get into GSoC?
# Cosine Similarity : 0.5168446898460388
#
#
# Document: How did Lucifer and Gabrielle relate to each other?
# Cosine Similarity : 0.5166022777557373
#
#
# Document: How can I be like Jake Williams?
# Cosine Similarity : 0.516197681427002
#
#
# Document: I got jio sim on 25th aug it is 4rth sep but still sim is not activated what I should do?
# Cosine Similarity : 0.5161594152450562
#
#
# Document: If you could go back in time and redo one thing, what would it be?
# Cosine Similarity : 0.5160878300666809
#
#
# Document: How do you answer a question on Quora?
# Cosine Similarity : 0.5159144997596741
#
#
# Document: What does @ mean as an emoticon?
# Cosine Similarity : 0.5157927870750427
#
#
# Document: Why is there no c flat in music?
# Cosine Similarity : 0.5154935717582703
#
#
# Document: How was it to meet Richard Feynman?
# Cosine Similarity : 0.5154920220375061
#
#
# Document: What is Shah Rukh Khan doing now?
# Cosine Similarity : 0.5154688358306885
#
#
# Document: What is the meaning of imperialism?
# Cosine Similarity : 0.5154656171798706
#
#
# Document: What is Oort cloud?
# Cosine Similarity : 0.5153082013130188
#
#
# Document: What's 2 pi?
# Cosine Similarity : 0.5152446627616882
#
#
# Document: What does litmus paper do and how is it made?
# Cosine Similarity : 0.5151957273483276
#
#
# Document: How do you type a facepalm in text?
# Cosine Similarity : 0.5151245594024658
#
#
# Document: What is the name of the song in which picturized on Madhuri Dixit and Ranbir Kapoor and is from which movie?
# Cosine Similarity : 0.5150147676467896
#
#
# Document: How does time exist?
# Cosine Similarity : 0.5148650407791138
#
#
# Document: What is a vision?
# Cosine Similarity : 0.5147732496261597
#
#
# Document: Does Reliance’s Jio 4G network work in Andaman and Nicobar islands, especially in its capital Port Blair?
# Cosine Similarity : 0.5147577524185181
#
#
# Document: How do I access Torbox in India?
# Cosine Similarity : 0.5145844221115112
#
#
# Document: How do I post a question in Quora?
# Cosine Similarity : 0.514581561088562
#
#
# Document: How do you post a question on Quora?
# Cosine Similarity : 0.514581561088562
#
#
# Document: What is the biggest facepalm moment you have ever experienced during an examination?
# Cosine Similarity : 0.5145230889320374
#
#
# Document: How can we check whether a number is prime or not?
# Cosine Similarity : 0.5144203901290894
#
#
# Document: What are the 7 strongest hokages?
# Cosine Similarity : 0.5142569541931152
#
#
# Document: What is a dangling bond?
# Cosine Similarity : 0.5140835642814636
#
#
# Document: What are some Cyanide and Happiness comics on countries?
# Cosine Similarity : 0.5138633847236633
#
#
# Document: How do we know that 1 second is 1 second?
# Cosine Similarity : 0.5138528347015381
#
#
# Document: Have you ever taken revenge? How and why did you take it?
# Cosine Similarity : 0.5138211846351624
#
#
# Document: Where can I get a time machine?
# Cosine Similarity : 0.5138077139854431
#
#
# Document: Were there any slave with the name Reddice?
# Cosine Similarity : 0.5137910842895508
#
#
# Document: What is the best crossover setting for subwoofer?
# Cosine Similarity : 0.5135594606399536
#
#
# Document: What is the essence of enlightenment?
# Cosine Similarity : 0.5135453343391418
#
#
# Document: What is the difference between bay, gulf and straits?
# Cosine Similarity : 0.5134503245353699
#
#
# Document: How do I simplify 5/x-y +3/y^2-x^2?
# Cosine Similarity : 0.5131742358207703
#
#
# Document: How can I find my epf number?
# Cosine Similarity : 0.5128962993621826
#
#
# Document: Why do not photons obey E = m c ^ 2?
# Cosine Similarity : 0.5128943920135498
#
#
# Document: Is astrology true? Should we believe it or not?
# Cosine Similarity : 0.5128734707832336
#
#
# Document: What are the lyrics to "Vivre Sans Temps Mort" by Double Dagger?
# Cosine Similarity : 0.5127400755882263
#
#
# Document: What's the difference between centripetal, tangential and angular acceleration?
# Cosine Similarity : 0.5123624801635742
#
#
# Document: What is an intercept column?
# Cosine Similarity : 0.5118547677993774
#
#
# Document: How do you delete a question you asked on Quora
# Cosine Similarity : 0.5118219256401062
#
#
# Document: Why did Malala Yousafzai win the Nobel Prize?
# Cosine Similarity : 0.5116526484489441
#
#
# Document: Who will win IPL 2016?
# Cosine Similarity : 0.511549174785614
#
#
# Document: How is the word "capricious" used in a sentence?
# Cosine Similarity : 0.5111051797866821
#
#
# Document: What are DOM charges in SBI?
# Cosine Similarity : 0.5110175013542175
#
#
# Document: What do you mean by financial statement analysis?
# Cosine Similarity : 0.510744035243988
#
#
# Document: What is the difference between blood group O neg and O rh neg?
# Cosine Similarity : 0.510738730430603
#
#
# Document: How is the word 'ubiquitous' used in a sentence?
# Cosine Similarity : 0.5103319883346558
#
#
# Document: Who named earth?
# Cosine Similarity : 0.510323166847229
#
#
# Document: Why is Salman Khan so overrated?
# Cosine Similarity : 0.5100803375244141
#
#
# Document: Will there be another billion dollar lottery Jackpot?
# Cosine Similarity : 0.5100236535072327
#
#
# Document: In what sectors is it best to live in Gurgaon?
# Cosine Similarity : 0.5099916458129883
#
#
# Document: How much will the price of gold fall?
# Cosine Similarity : 0.5099475383758545
#
#
# Document: What are some synonyms for "results-oriented"?
# Cosine Similarity : 0.5097728967666626
#
#
# Document: Is there any formula for finding nth prime number?
# Cosine Similarity : 0.5095570087432861
#
#
# Document: Which is the most awesome way to die?
# Cosine Similarity : 0.5095478296279907
#
#
# Document: In C++, what are access modifiers?
# Cosine Similarity : 0.5095033645629883
#
#
# Document: What part did the bureaucracy get to play in the run up to the recent demonetization move of GOI?
# Cosine Similarity : 0.5094384551048279
#
#
# Document: Did dunno create the universe?
# Cosine Similarity : 0.5093498229980469
#
#
# Document: What is the aim?
# Cosine Similarity : 0.509314239025116
#
#
# Document: What was the significance of showing Amitabh Bachchan with a mask in the movie PINK?
# Cosine Similarity : 0.509213924407959
#
#
# Document: What is the difference between CDMA and GSM?
# Cosine Similarity : 0.5091620087623596
#
#
# Document: How can I become a billionaire in mindset?
# Cosine Similarity : 0.5091089010238647
#
#
# Document: What is the actual source of gravity?
# Cosine Similarity : 0.5090881586074829
#
#
# Document: Who is going to win the 8th season of the IPL and why?
# Cosine Similarity : 0.5090090036392212
#
#
# Document: How much is the tilt of the earth's axis?
# Cosine Similarity : 0.5089443922042847
#
#
# Document: Why are INTJs and INTPs so popular on Quora?
# Cosine Similarity : 0.5088524222373962
#
#
# Document: What is the meaning of Hindi/Urdu word 'Shiksha' and 'Taleem'?
# Cosine Similarity : 0.5087975263595581
#
#
# Document: How do I import artifacts?
# Cosine Similarity : 0.508796215057373
#
#
# Document: Is evolution real? How has this been proven?
# Cosine Similarity : 0.5087780356407166
#
#
# Document: What is a quantum watch?
# Cosine Similarity : 0.5086894035339355
#
#
# Document: If more vacuum energy appears with expansion and it has no limit, can infinite of this energy be created? If yes is energy infinite?
# Cosine Similarity : 0.5085628032684326
#
#
# Document: What are shot narrative paragraphs? What are some examples?
# Cosine Similarity : 0.5083199739456177
#
#
# Document: Why is editorial page of The Hindu so important for UPSC aspirants?
# Cosine Similarity : 0.5082600116729736
#
#
# Document: Which is stronger titanium or diamonds?
# Cosine Similarity : 0.5082483887672424
#
#
# Document: How do you find the [math]\frac{dy}{dx}[/math] of [math]\tan\left(\frac{x}{y}\right) =x+y[/math]?
# Cosine Similarity : 0.5081874132156372
#
#
# Document: How do I find heroes in my life?
# Cosine Similarity : 0.508084237575531
#
#
# Document: Are there more colors in a rainbow than the seven usually mentioned?
# Cosine Similarity : 0.5080370903015137
#
#
# Document: What is the mitochondria? What is the main function?
# Cosine Similarity : 0.5080001354217529
#
#
# Document: How could we know that we are falling in love?
# Cosine Similarity : 0.5079548358917236
#
#
# Document: What is actually happening in Aleppo?
# Cosine Similarity : 0.507909893989563
#
#
# Document: What are the best branches at NIT Jamshedpur?
# Cosine Similarity : 0.5078655481338501
#
#
# Document: How can I promote Udemy course?
# Cosine Similarity : 0.5078520774841309
#
#
# Document: What is the life of ies?
# Cosine Similarity : 0.5077633857727051
#
#
# Document: What are some unwritten rules in USA?
# Cosine Similarity : 0.5076062679290771
#
#
# Document: What is my puk code?
# Cosine Similarity : 0.507532000541687
#
#
# Document: Is there a astronomical model that would generate the very long seasons found in Westeros/Essos?
# Cosine Similarity : 0.5075187087059021
#
#
# Document: How does 3D printing work?
# Cosine Similarity : 0.5074835419654846
#
#
# Document: Can I get into M.tech program through UPSEE?
# Cosine Similarity : 0.5074445605278015
#
#
# ...
# Cosine Similarity : 0.14003896713256836
#
#
# Document: How will the scrapping of Rs 500 and Rs 1000 notes help in reducing black money and corruption?
# Cosine Similarity : 0.13941790163516998
#
#
# Document: How do I improve diet to gain weight? What are other options to gain weight?
# Cosine Similarity : 0.13925938308238983
#
#
# Document: What are the meal plans for the Dr.Moreno's 17 day diet?
# Cosine Similarity : 0.1390569508075714
#
#
# Document: How can Activia yogurt aid with weight loss?
# Cosine Similarity : 0.1389722377061844
#
#
# Document: At what age do puppies stop biting?
# Cosine Similarity : 0.13872922956943512
#
#
# Document: How can I help or encourage my mother to lose weight?
# Cosine Similarity : 0.13852320611476898
#
#
# Document: How do I start a grocery shop online?
# Cosine Similarity : 0.13832741975784302
#
#
# Document: What are some online resources to learn UI design?
# Cosine Similarity : 0.1381889134645462
#
#
# Document: What do astronauts aboard ISS do when a solar storm is headed there way?
# Cosine Similarity : 0.13700629770755768
#
#
# Document: Does green tea really help in losing weight?
# Cosine Similarity : 0.13679984211921692
#
#
# Document: Where can I learn more about mental balance according to Chinese medicine as a Western guy?
# Cosine Similarity : 0.13679757714271545
#
#
# Document: How do I learn to play soccer?
# Cosine Similarity : 0.1356903314590454
#
#
# Document: Where does the water from the Great Lakes come from, and how does these lakes wildlife compare to Lake Prespa?
# Cosine Similarity : 0.1349993199110031
#
#
# Document: How should a teacher maintain discipline in the classroom?
# Cosine Similarity : 0.13487406075000763
#
#
# Document: What online grocery/food delivery services accept EBT cards/food stamps?
# Cosine Similarity : 0.13484323024749756
#
#
# Document: I want to meet an introverted man, where should I go? I hate bars/clubs and know I would never meet the person I want to be with there.
# Cosine Similarity : 0.13479222357273102
#
#
# Document: How can I get MOOC/E-learning through online web and video courses related to filmmaking & production developed by Indian professors?
# Cosine Similarity : 0.1346004605293274
#
#
# Document: Why do some people bully others? Why some of them have pleasure on bullying others?
# Cosine Similarity : 0.13403715193271637
#
#
# Document: How long does a routine dental checkup normally take in the U.S., if the patient is perfectly healthy and schedules one every six months?
# Cosine Similarity : 0.13401034474372864
#
#
# Document: Why hasn't anyone 3D printed beds for prisons yet to reduce ability to fashion weapons out of metal and therefore reduce violence?
# Cosine Similarity : 0.1339607536792755
#
#
# Document: How do I identify adulterated milk and milk products at a home level without using chemicals?
# Cosine Similarity : 0.1338750720024109
#
#
# Document: I am 29Y old. I have diabetic Type 2. Recently my sugar level was increased to 150 (fasting). I do exercise and eat whole grains. why this happening?
# Cosine Similarity : 0.13375815749168396
#
#
# Document: Harvard College Courses: What is general shopping advice for Turkish classes?
# Cosine Similarity : 0.13368818163871765
#
#
# Document: Is there a way to get a user's friends' email address through Facebook API for php?
# Cosine Similarity : 0.1332045942544937
#
#
# Document: How do I learn strumming on a guitar?
# Cosine Similarity : 0.13278383016586304
#
#
# Document: How do you cook bacon without an oven or microwave?
# Cosine Similarity : 0.1327446699142456
#
#
# Document: What movie website can I watch movies on without credit card information?
# Cosine Similarity : 0.13273552060127258
#
#
# Document: What side dishes go well with hamburgers?
# Cosine Similarity : 0.13272534310817719
#
#
# Document: What is it like at the University of Chicago? How are the students and the professors?
# Cosine Similarity : 0.13196152448654175
#
#
# Document: How difficult is it to get a permission for shooting in local trains and stations for students?
# Cosine Similarity : 0.13195732235908508
#
#
# Document: Can you feed pork rib bones to dogs?
# Cosine Similarity : 0.13095757365226746
#
#
# Document: Do cricket players really drink tea on a tea break?
# Cosine Similarity : 0.1307165026664734
#
#
# Document: How does Peapod compare with other online grocery services like Safeway and Amazon Fresh?
# Cosine Similarity : 0.13065417110919952
#
#
# Document: Why do some dogs like to eat poo?
# Cosine Similarity : 0.13043466210365295
#
#
# Document: Are there People who are willing to give free lectures or conduct free workshop in India colleges?
# Cosine Similarity : 0.13022518157958984
#
#
# Document: Can being bullied or having less sleep cause social anxiety?
# Cosine Similarity : 0.1301773339509964
#
#
# Document: What is served for breakfast on a typical US army base?
# Cosine Similarity : 0.12940241396427155
#
#
# Document: Why don't turbofans have grilles at the inlet to prevent large objects such as birds and debris from entering?
# Cosine Similarity : 0.12918603420257568
#
#
# Document: Will I lose weight by only drinking water?
# Cosine Similarity : 0.1287260353565216
#
#
# Document: How can you use dish soap in a dishwasher?
# Cosine Similarity : 0.12802010774612427
#
#
# Document: What are your favorite Chinese foods?
# Cosine Similarity : 0.1276281774044037
#
#
# Document: Is it healthy to eat one chicken every day?
# Cosine Similarity : 0.12747731804847717
#
#
# Document: How do I learn some simple, practical ways of doing meditation?
# Cosine Similarity : 0.12705641984939575
#
#
# Document: My dog can't really move after his bath. What do I do?
# Cosine Similarity : 0.12588466703891754
#
#
# Document: What is the best dry dog food brand for picky eaters?
# Cosine Similarity : 0.12430612742900848
#
#
# Document: How does the tap water distribution and sewage disposal system work in Kolkata?
# Cosine Similarity : 0.1242019459605217
#
#
# Document: Dermatology: What are some best practices for treating bacterial scalp folliculitis?
# Cosine Similarity : 0.12349288165569305
#
#
# Document: Why do oil heaters (room heaters) have fans. Do they burn oxygen, too?
# Cosine Similarity : 0.12324237823486328
#
#
# Document: I recently got the news about my dog's bone cancer. Can somebody give some experienced Vet's number who could somehow save him?
# Cosine Similarity : 0.12302838265895844
#
#
# Document: Is it legal for traffic police to stand in the middle of the road to stop vehicles?
# Cosine Similarity : 0.12291881442070007
#
#
# Document: Can kittens eat watermelon? If not, why?
# Cosine Similarity : 0.12266527861356735
#
#
# Document: I wanted to start a e-grocery store in Kerala. So will any of the existing e-grocery stores in India will allow me to visit and study their office?
# Cosine Similarity : 0.12224114686250687
#
#
# Document: Why do some of my black friends hate white people?
# Cosine Similarity : 0.12214431911706924
#
#
# Document: How is the restaurant business?
# Cosine Similarity : 0.12099810689687729
#
#
# Document: Why do fashion designers create weird clothes that they don't sell at shops?
# Cosine Similarity : 0.12096293270587921
#
#
# Document: How could one get a job in Nestle being a fresher with a degree in food processing and technology engineering?
# Cosine Similarity : 0.12057030200958252
#
#
# Document: What are good gifts for a foreign visitor to bring when they're invited to someone's home in Turkey for the first time?
# Cosine Similarity : 0.12054408341646194
#
#
# Document: How can I learn how to play the piano?
# Cosine Similarity : 0.12035391479730606
#
#
# Document: How much water should a normal, healthy adult drink on a daily basis to avoid dehydration?
# Cosine Similarity : 0.12032242119312286
#
#
# Document: How do we avoid whey in Yogurt?
# Cosine Similarity : 0.12021347880363464
#
#
# Document: Is there a special dish/food from your home country that your family has incorporated into the traditional American Thanksgiving meal?
# Cosine Similarity : 0.11975590139627457
#
#
# Document: How can I get MOOC/E-learning through online web and video courses related to paramedical sciences developed by Indian professors?
# Cosine Similarity : 0.11968091875314713
#
#
# Document: Which pizzas are the most popularly ordered pizzas on Domino's menu?
# Cosine Similarity : 0.11952737718820572
#
#
# Document: Do other cars taunt you while you are driving in public?
# Cosine Similarity : 0.11873255670070648
#
#
# Document: How widely accepted are credit cards at small businesses and restaurants in Brazil?
# Cosine Similarity : 0.11812607944011688
#
#
# Document: How is China attempting to reduce its air pollution?
# Cosine Similarity : 0.11783014237880707
#
#
# Document: SOS: I forgot to take the piece of tissue paper out of my trousers' pocket before washing them with my other clothes in my washing machine. Now all my washed clothes are full with residue of that piece of tissue paper. What's the best solution to solve this problem?
# Cosine Similarity : 0.11755248159170151
#
#
# Document: What does it mean if a dog vomits white foam?
# Cosine Similarity : 0.11733634769916534
#
#
# Document: How do I promote my custom-made wooden furniture manufacturing business?
# Cosine Similarity : 0.11713238060474396
#
#
# Document: How can I ask a supermarket owner to put an advertisement photo of my new product in the supermarket entrance?
# Cosine Similarity : 0.11689890921115875
#
#
# Document: What are the qualifications of professional food tasters?
# Cosine Similarity : 0.1163860559463501
#
#
# Document: How do you make fresh lemonade?
# Cosine Similarity : 0.11594927310943604
#
#
# Document: Why is reducing individual and societal ecological footprint necessary and important?
# Cosine Similarity : 0.11581020057201385
#
#
# Document: How can eating prunes help during a constipation?
# Cosine Similarity : 0.11510659754276276
#
#
# Document: How do I kill a small animal with toothpaste and jam?(Just a thought I happened to have, I dont plan on killing any animals nor do i want to)
# Cosine Similarity : 0.11486723273992538
#
#
# Document: What kind of doctor should I go to that treats mental health problems with diet, supplements, etc?
# Cosine Similarity : 0.11485321819782257
#
#
# Document: What Quora user would you most like to have lunch with?
# Cosine Similarity : 0.11403194069862366
#
#
# Document: Why are people who are not vegan so vehement in criticizing vegans who live with vegan dogs?
# Cosine Similarity : 0.11327371001243591
#
#
# Document: Which option is better to reduce weight, swimming or gym?
# Cosine Similarity : 0.11317557841539383
#
#
# Document: Can we charge laptops via USB with a power bank?
# Cosine Similarity : 0.11262379586696625
#
#
# Document: How can Google Analytics data and machine learning help an online business?
# Cosine Similarity : 0.11253691464662552
#
#
# Document: When wild humans are found in the wild, why are people using the word "rescue" from his/her animal families when they're actually kidnapping him/her?
# Cosine Similarity : 0.11129538714885712
#
#
# Document: Do cops really check the license plate of the car in front of them?
# Cosine Similarity : 0.11113064736127853
#
#
# Document: How do I learn acoustic guitar at home?
# Cosine Similarity : 0.11057563126087189
#
#
# Document: Which is better: reading manga or watching anime?
# Cosine Similarity : 0.11026815325021744
#
#
# Document: How can I find a job at Iskcon or some ashram so that I could follow brahmacharya and also earn to fulfil basic needs like food, medicine etc?
# Cosine Similarity : 0.10922074317932129
#
#
# Document: Carolina Panthers Live Streaming | Watch Carolina Panthers Live Stream NFL Games Today Online?
# Cosine Similarity : 0.10824717581272125
#
#
# Document: Is it ok to feed asparagus to dogs?
# Cosine Similarity : 0.10787966102361679
#
#
# Document: Is organic food really healthier? Is it more nutritious?
# Cosine Similarity : 0.10726329684257507
#
#
# Document: Why do joggers early in the morning and in the evening wear dark clothes and run in the streets without a flashlight, even when there are sidewalks?
# Cosine Similarity : 0.10582512617111206
#
#
# Document: Can dogs eat grape jelly? Why or why not?
# Cosine Similarity : 0.10519383102655411
#
#
# Document: How would you order these four cities (Bangalore, Chennai, Hyderabad, Pune) for living (considering climate, people, food, future growth, safety, cost of living, etc.)?
# Cosine Similarity : 0.10400643199682236
#
#
# Document: My family doesn't respect my contribution to chores, office work. They talk disrespectfully & get verbally aggressive. What to do.?
# Cosine Similarity : 0.1039818674325943
#
#
# Document: How can I make a healthy home made pizza?
# Cosine Similarity : 0.10347089171409607
#
#
# Document: Which institutions in Kolkata give coaching for entrance exams for a master's in political science?
# Cosine Similarity : 0.10314653068780899
#
#
# Document: What are some examples of animals that eat both plants and animals?
# Cosine Similarity : 0.10277418047189713
#
#
# Document: Can I feed my dog asparagus? Is it harmful for him?
# Cosine Similarity : 0.10181289911270142
#
#
# Document: How cosmonauts/astronauts are located inside Soyuz spacecraft?
# Cosine Similarity : 0.10075802356004715
#
#
# Document: How do pilots avoid turbulence?
# Cosine Similarity : 0.10028187930583954
#
#
# Document: How do I learn about computer programming, networking and computer hardware?
# Cosine Similarity : 0.10023099929094315
#
#
# Document: Should the toothbrush be wet or dry before applying the toothpaste?
# Cosine Similarity : 0.0988171175122261
#
#
# Document: Which one of this is correct: I had my lunch, I have had my lunch, I have ate my lunch?
# Cosine Similarity : 0.09752249717712402
#
#
# Document: Where can I learn about reading and understanding the log files in my Mac's Console?
# Cosine Similarity : 0.09614258259534836
#
#
# Document: If I skip breakfast and lunch, and only have dinner and two cups of coffee in a whole day, will I lose weight?
# Cosine Similarity : 0.09261054545640945
#
#
# Document: A couple who has 5 sons went for a picnic. Each son has 7 sisters. Each sister has 3 babies. In total, how many people went for the picnic?
# Cosine Similarity : 0.0925542563199997
#
#
# Document: Why are there no healthy fast food restaurants?
# Cosine Similarity : 0.0918697714805603
#
#
# Document: What same food should I eat every day to protect my health?
# Cosine Similarity : 0.09115447103977203
#
#
# Document: I have seen porn stars lick the asshole of the partner they will be doing. Isn't that disgusting? How do you eat food afterwards?
# Cosine Similarity : 0.09018321335315704
#
#
# Document: In which countries can dogs travel on public transportation without a muzzle?
# Cosine Similarity : 0.08895622193813324
#
#
# Document: Are there any universities that teach film production to people who have no filmmaking experience?
# Cosine Similarity : 0.08309223502874374
#
#
# Document: If a guy asks a girl out to dinner, when is it a date and when is it not a date?
# Cosine Similarity : 0.08292120695114136
#
#
# Document: When a police officer pulls you over and you drive into your own driveway, what will the police do?
# Cosine Similarity : 0.08035974204540253
#
#
# Document: How do I survive the competition in online food ordering (middleman) business?
# Cosine Similarity : 0.07292407751083374
#
#
# Document: Will eating large amounts of yogurt make me sick?
# Cosine Similarity : 0.07152160257101059
#
#
# Document: If a tow truck is about to tow your car, can you get in the car and refuse to have it towed?
# Cosine Similarity : 0.06922557204961777
#
#
# Document: How do I get driving license in India for driving Volvo air bus, lorry and truck? Where can I learn driving bus, lorry and truck in Chennai?
# Cosine Similarity : 0.05907950550317764
#
#
# Document: Can we eat meat with dairy products?
# Cosine Similarity : 0.0582580603659153
#
#
# Document: Three upperclassmen at my school jokingly pull their pants all the way down when urinating. How can I properly express my disgust?
# Cosine Similarity : 0.054911524057388306
#
#
# Document: Is drinking milk good if I am aiming for fat loss by maintaining a low calorie diet? Also is it advisable to drink milk before a workout?
# Cosine Similarity : 0.04834221303462982
#
#
# Document: Do vegetarians feed their dogs with meat?
# Cosine Similarity : 0.014308520592749119

# %%
# Euclidean Distance for first document
i = 1  # document serial number  in corpus
print (f'Document: {questions_df.iloc[i]["question"]}')
print ('\n')
print (f'Similar Documents using Cosine Similarity:')
difference_ix=np.argsort(pairwise_differences[i])
for ix in difference_ix:
        if ix==i:
            continue
        print('\n')
        print (f'Document: {questions_df.iloc[ix]["question"]}')
        print (f'Euclidean Distance : {pairwise_differences[i][ix]}')
# Out:
# Document: What is the story of Kohinoor (Koh-i-Noor) Diamond?
#
#
# Similar Documents using Cosine Similarity:
#
#
# Document: How do I Import diamonds from India?
# Euclidean Distance : 12.455949783325195
#
#
# Document: What is this triple talaq issue all about?
# Euclidean Distance : 12.484404563903809
#
#
# Document: A title for my continuation to The Gift of the Magi?
# Euclidean Distance : 12.70783805847168
#
#
# Document: What prompted Wheel of Fortune to use the letters R S T L N and E in the bonus round?
# Euclidean Distance : 12.885248184204102
#
#
# Document: What do you think about the Bajaj Dominar 400?
# Euclidean Distance : 13.010278701782227
#
#
# Document: Who was Koundinya Rishi?
# Euclidean Distance : 13.091779708862305
#
#
# Document: Where is Nangli Wazidpur?
# Euclidean Distance : 13.112984657287598
#
#
# Document: What is going on between Hrithik roshan & Kangana Ranawat?
# Euclidean Distance : 13.122075080871582
#
#
# Document: What does each line mean from the song STARBOY by Weeknd ?
# Euclidean Distance : 13.205232620239258
#
#
# Document: Why is sandeep maheshwari not on Quora?
# Euclidean Distance : 13.23614501953125
#
#
# Document: How do you tell a narcissist they are narcissist?
# Euclidean Distance : 13.370594024658203
#
#
# Document: Why is Manaphy so whiny?
# Euclidean Distance : 13.384665489196777
#
#
# Document: Is Jamie Azor Ahai?
# Euclidean Distance : 13.451032638549805
#
#
# Document: Will Modi win in 2019?
# Euclidean Distance : 13.456158638000488
#
#
# Document: Boon and bane of supplementary exams?
# Euclidean Distance : 13.487442016601562
#
#
# Document: Stphen william hawking?
# Euclidean Distance : 13.552043914794922
#
#
# Document: What does magizhchi mean?
# Euclidean Distance : 13.700587272644043
#
#
# Document: What are the effects of Shani sade sati?
# Euclidean Distance : 13.714642524719238
#
#
# Document: What happened to David dvdasa?
# Euclidean Distance : 13.763774871826172
#
#
# Document: What is triloca.com?
# Euclidean Distance : 13.784759521484375
#
#
# Document: How much does Kapil Sharma charge for a show?
# Euclidean Distance : 13.80643367767334
#
#
# Document: What is Quora, and what is the relevence?
# Euclidean Distance : 13.815267562866211
#
#
# Document: What are the diamond shaped structures in the middle of railway tracks?
# Euclidean Distance : 13.853227615356445
#
#
# Document: The prime factorization of intezer N is A x A x B x C, where A, B and C are all distinct prine intezers. How many factors does N have?
# Euclidean Distance : 13.89794635772705
#
#
# Document: What does the Quran say about triple talaq?
# Euclidean Distance : 13.927140235900879
#
#
# Document: What should I do to become an RJ in Indore?
# Euclidean Distance : 13.930957794189453
#
#
# Document: What Anna Hazare think about PM Modi?
# Euclidean Distance : 13.93480396270752
#
#
# Document: How do I root Micromax Canvas Knight Cameo?
# Euclidean Distance : 13.9491605758667
#
#
# Document: What is a Darth?
# Euclidean Distance : 13.953073501586914
#
#
# Document: What is Jan lokapal bill?
# Euclidean Distance : 13.98070240020752
#
#
# Document: What should I do after a BTech in CSE?
# Euclidean Distance : 13.989035606384277
#
#
# Document: Is Sadhguru a conman?
# Euclidean Distance : 14.00880241394043
#
#
# Document: What does NAFTA stand for?
# Euclidean Distance : 14.013940811157227
#
#
# Document: What is the meaning of the name Athira?
# Euclidean Distance : 14.052742004394531
#
#
# Document: Is 1 to the power infinity =1?
# Euclidean Distance : 14.05471420288086
#
#
# Document: How can I tell if I’m a narcissist?
# Euclidean Distance : 14.061070442199707
#
#
# Document: How is imagery used in "David" by Earle Birney?
# Euclidean Distance : 14.065557479858398
#
#
# Document: What do you think of Shifuji Shaurya Bhardwaj?
# Euclidean Distance : 14.079944610595703
#
#
# Document: Why did harry become a horcrux?
# Euclidean Distance : 14.113399505615234
#
#
# Document: What is the OBC cut off for IIFT 2015?
# Euclidean Distance : 14.136780738830566
#
#
# Document: What is the IIT, Roorkee cutoff for instrumentation?
# Euclidean Distance : 14.15140438079834
#
#
# Document: What is the difference between INFJ-T and INFJ-A?
# Euclidean Distance : 14.153809547424316
#
#
# Document: How can you tell if you are a narcissist?
# Euclidean Distance : 14.154707908630371
#
#
# Document: Is declartion statement reuired in a resume?
# Euclidean Distance : 14.161680221557617
#
#
# Document: How do I my epf account no I have my uan?
# Euclidean Distance : 14.192138671875
#
#
# Document: If I give IIM A B and C 5 stars each, how do you rate L I and K?
# Euclidean Distance : 14.227231979370117
#
#
# Document: What is the symbol for coppertone stock?
# Euclidean Distance : 14.237581253051758
#
#
# Document: What is the effect of demonetization of 500 and 1000 rupees note?
# Euclidean Distance : 14.242703437805176
#
#
# Document: What should you engrave on promise rings?
# Euclidean Distance : 14.242840766906738
#
#
# Document: What is the best way to make a responsive grid of "diamond shapes"?
# Euclidean Distance : 14.25297737121582
#
#
# Document: Why is Jean Claude Van Damme not in The Expendables?
# Euclidean Distance : 14.260735511779785
#
#
# Document: Where can I get the Jacket that Ranbir Kapoor is wearing in song 'Matargashti'?
# Euclidean Distance : 14.265043258666992
#
#
# Document: What are some lesser known facts about Taarak Mehta Ka Ooltah Chashmah?
# Euclidean Distance : 14.285571098327637
#
#
# Document: What does "lien amount" in the SBI mean?
# Euclidean Distance : 14.29051399230957
#
#
# Document: Who owns Punreal.com?
# Euclidean Distance : 14.299054145812988
#
#
# Document: Can I use IRCTC eWallet for Tatkal Booking?
# Euclidean Distance : 14.314947128295898
#
#
# Document: Is infinity a number?
# Euclidean Distance : 14.318676948547363
#
#
# Document: What individuals and events in history are a source of pride for São Tomé and Príncipe?
# Euclidean Distance : 14.321996688842773
#
#
# Document: How TQWL is different from CKWL (Tatkal waiting list)?
# Euclidean Distance : 14.337922096252441
#
#
# Document: How would an arbitrageur seek to capitalize given the following conditions: S0 + Pa (S0,T,X) < Ca (S0,T,X) + X (l + r) ^(-T)?
# Euclidean Distance : 14.341008186340332
#
#
# Document: How do I know if I'm a narcissist?
# Euclidean Distance : 14.353741645812988
#
#
# Document: What is the best way to counter Meepo in Dota 2?
# Euclidean Distance : 14.35630989074707
#
#
# Document: Why is The Count of Monte Cristo so long?
# Euclidean Distance : 14.366151809692383
#
#
# Document: What is Jeffrey Kearns' opinion on Khan Academy?
# Euclidean Distance : 14.376688003540039
#
#
# Document: Which DLP is the best for the JEE?
# Euclidean Distance : 14.383183479309082
#
#
# Document: What is the difference between zamindari, ryotwari and mahalwari system?
# Euclidean Distance : 14.384147644042969
#
#
# Document: What is Vyvanse used for?
# Euclidean Distance : 14.38609790802002
#
#
# Document: What's the placement scenario for an MTech in Instrumentation at NIT Agartala?
# Euclidean Distance : 14.386972427368164
#
#
# Document: What is the chord progression in Underworld's "8 Ball"?
# Euclidean Distance : 14.387308120727539
#
#
# Document: What is illuminati? What does it do?
# Euclidean Distance : 14.390366554260254
#
#
# Document: How do I get addmision in MIT?
# Euclidean Distance : 14.393025398254395
#
#
# Document: What does "Quora " mean?
# Euclidean Distance : 14.4060640335083
#
#
# Document: Could the RPK be belt-fed?
# Euclidean Distance : 14.416433334350586
#
#
# Document: Who is blasie pascal?
# Euclidean Distance : 14.418242454528809
#
#
# Document: Are there other equivalents of the Wights in ASOIAF?
# Euclidean Distance : 14.425799369812012
#
#
# Document: What is the "Anaar ke chilke ka totka " of GD Vasistha for debt returning?
# Euclidean Distance : 14.427064895629883
#
#
# Document: What is cerber 3?
# Euclidean Distance : 14.434521675109863
#
#
# Document: How do I registered my moblie number for my aadhar card?
# Euclidean Distance : 14.450638771057129
#
#
# Document: How far would you go for love? Should I wait for the one I love ir move on?
# Euclidean Distance : 14.458380699157715
#
#
# Document: Is Illuminati a real theory?
# Euclidean Distance : 14.45975399017334
#
#
# Document: How is the word "jocund" used in a sentence?
# Euclidean Distance : 14.461532592773438
#
#
# Document: What is the meaning of the name Manishaa?
# Euclidean Distance : 14.47159194946289
#
#
# Document: How hard is the AWS Developer Associate certification?
# Euclidean Distance : 14.479915618896484
#
#
# Document: Is incognitovpn.com legit?
# Euclidean Distance : 14.48090648651123
#
#
# Document: What is the IELTS all about?
# Euclidean Distance : 14.482309341430664
#
#
# Document: Who own ygeia3.com?
# Euclidean Distance : 14.485841751098633
#
#
# Document: Why are the Seven Wonders of the World referred to as Wonders?
# Euclidean Distance : 14.487027168273926
#
#
# Document: How are YIF placements?
# Euclidean Distance : 14.493021011352539
#
#
# Document: What exactly is a backend developer?
# Euclidean Distance : 14.498517990112305
#
#
# Document: What does the exclamation point mean in excel?
# Euclidean Distance : 14.498703956604004
#
#
# Document: What is the most viewed answer you have got on Quora?
# Euclidean Distance : 14.499753952026367
#
#
# Document: What camera does Charles Trippy use?
# Euclidean Distance : 14.500042915344238
#
#
# Document: Who is Sai Rahul Paluvai? And why is he a legend?
# Euclidean Distance : 14.502650260925293
#
#
# Document: Who backs the insurance for Metromile?
# Euclidean Distance : 14.503393173217773
#
#
# Document: Which is best ejabberd or openfire?
# Euclidean Distance : 14.508705139160156
#
#
# Document: Who is Redd Foxx?
# Euclidean Distance : 14.510573387145996
#
#
# Document: What doe Quora mean?
# Euclidean Distance : 14.515353202819824
#
#
# Document: Why can I upvote this Quora question?
# Euclidean Distance : 14.528454780578613
#
#
# Document: What does my kundali reveal about my career?
# Euclidean Distance : 14.535721778869629
#
#
# Document: Why has the RBI launched the 1000 rupee coin? What is the significance of it?
# Euclidean Distance : 14.554031372070312
#
#
# Document: How do you put notes in a TI-84 Plus?
# Euclidean Distance : 14.557661056518555
#
#
# Document: What is this CH3 and H3C?
# Euclidean Distance : 14.579787254333496
#
#
# Document: What was it like to work with Satya Nadella?
# Euclidean Distance : 14.593422889709473
#
#
# Document: Does Sheldon, Penny, Leonard and Howard know about the 'caste' of Rajesh Koothrapalli?
# Euclidean Distance : 14.597399711608887
#
#
# Document: What happens when you combine H2O and CO2?
# Euclidean Distance : 14.602876663208008
#
#
# Document: Where can I find Kapoor and sons torrent?
# Euclidean Distance : 14.61990737915039
#
#
# Document: How can I solve arcsin (x^2) / x^2?
# Euclidean Distance : 14.627151489257812
#
#
# Document: Is VNIT tier 1 college?
# Euclidean Distance : 14.6277437210083
#
#
# Document: What are some of the truths about life in DU?
# Euclidean Distance : 14.6283597946167
#
#
# Document: What's your contribution to the world so far?
# Euclidean Distance : 14.632710456848145
#
#
# Document: For BITSAT & IIT JEE Mains 'theory', is NCERT sufficient?
# Euclidean Distance : 14.636727333068848
#
#
# Document: How is Dabba trading done?
# Euclidean Distance : 14.639863967895508
#
#
# Document: What is it like to be Jack Dorsey?
# Euclidean Distance : 14.659388542175293
#
#
# Document: How is the word 'valiant' used in a sentence?
# Euclidean Distance : 14.662812232971191
#
#
# Document: What it is like to work in RBI?
# Euclidean Distance : 14.667872428894043
#
#
# Document: What's your secret to success?
# Euclidean Distance : 14.673171997070312
#
#
# Document: What is the cutoff percentile for NITIE and MDI Gurgaon this year?
# Euclidean Distance : 14.68392562866211
#
#
# Document: What is the difference between final investigation report and jmfc 173 report?
# Euclidean Distance : 14.689794540405273
#
#
# Document: How is FIITJEE Delhi?
# Euclidean Distance : 14.691975593566895
#
#
# Document: Waht is diploid?
# Euclidean Distance : 14.69504165649414
#
#
# Document: How do you wear a promise ring?
# Euclidean Distance : 14.700122833251953
#
#
# Document: In the play "A Raisin in the Sun", why do Walter ad Beneatha argue?
# Euclidean Distance : 14.701595306396484
#
#
# Document: What is the expected neet 2 cutoff?
# Euclidean Distance : 14.705179214477539
#
#
# Document: Why should I answer in Quora?
# Euclidean Distance : 14.718323707580566
#
#
# Document: Why are most Quora answers so long?
# Euclidean Distance : 14.721542358398438
#
#
# Document: What are some iconic quotes about Rahul Dravid?
# Euclidean Distance : 14.723358154296875
#
#
# Document: How was the KVPY 2016 sa?
# Euclidean Distance : 14.735578536987305
#
#
# Document: How was your KVPY sa 2016?
# Euclidean Distance : 14.735578536987305
#
#
# Document: What are the Keys to the Kingdom?
# Euclidean Distance : 14.739823341369629
#
#
# Document: What is the difference between Worldpay and Stripe?
# Euclidean Distance : 14.743803024291992
#
#
# Document: Is our PM Modi doing the correct thing with 500 and 1000 Rs notes?
# Euclidean Distance : 14.74517822265625
#
#
# Document: National Anthems: Do anyone know from which novel Jana Gana Mana is taken?
# Euclidean Distance : 14.759413719177246
#
#
# Document: Why is it taking so long for Pokémon GO to be available in India?
# Euclidean Distance : 14.776590347290039
#
#
# Document: What does a double triangle tattoo mean?
# Euclidean Distance : 14.78666877746582
#
#
# Document: How can I meet Suresh Raina?
# Euclidean Distance : 14.807602882385254
#
#
# Document: How do I get off Quora?
# Euclidean Distance : 14.807682991027832
#
#
# Document: How is the movie MS Dhoni untold story?
# Euclidean Distance : 14.80781078338623
#
#
# Document: How can I get job in Accenture?
# Euclidean Distance : 14.814224243164062
#
#
# Document: How can I get free gems in Clash of Clans?
# Euclidean Distance : 14.82712459564209
#
#
# Document: What's the meaning of the "Triune God"?
# Euclidean Distance : 14.841731071472168
#
#
# Document: Who according to you is a hero? Why?
# Euclidean Distance : 14.845752716064453
#
#
# Document: What is the Tumblr story?
# Euclidean Distance : 14.846511840820312
#
#
# Document: How long does it take to get an offer?
# Euclidean Distance : 14.852230072021484
#
#
# Document: What is the difference between BPEL, BPMN and BPM?
# Euclidean Distance : 14.859554290771484
#
#
# Document: Why does noone see the diference between Endless and Infinite?
# Euclidean Distance : 14.861435890197754
#
#
# Document: What is my GPA if I have scored 65% in my 11th std CBSE?
# Euclidean Distance : 14.861800193786621
#
#
# Document: Are Pixotine coupon Codes available?
# Euclidean Distance : 14.865086555480957
#
#
# Document: When will Pokémon GO release in India?
# Euclidean Distance : 14.866485595703125
#
#
# Document: What are 5 facts about the earth's crust?
# Euclidean Distance : 14.876944541931152
#
#
# Document: What is the power of a dream?
# Euclidean Distance : 14.881789207458496
#
#
# Document: What is the meaning of para and gravida?
# Euclidean Distance : 14.887434005737305
#
#
# Document: What is the all-time most viewed question on Quora?
# Euclidean Distance : 14.887612342834473
#
#
# Document: What would be next strike from PM Modi after Demonetisation?
# Euclidean Distance : 14.897181510925293
#
#
# Document: What is meant by "the language of a story"?
# Euclidean Distance : 14.902270317077637
#
#
# Document: How do delete Quora quesitons?
# Euclidean Distance : 14.904014587402344
#
#
# Document: CDSE 2016 merit list is already out. Is there a chance for TES 36 merit to come out in just few days?
# Euclidean Distance : 14.907448768615723
#
#
# Document: What is the difference between cetirizine and levocetirizine?
# Euclidean Distance : 14.912837982177734
#
#
# Document: Why do people belive in god?
# Euclidean Distance : 14.913960456848145
#
#
# Document: What's the difference between IT and COE at NSIT and DTU?
# Euclidean Distance : 14.92042350769043
#
#
# Document: Why does Ichigo have hollow powers?
# Euclidean Distance : 14.926974296569824
#
#
# Document: What is sensex? What is nifty?
# Euclidean Distance : 14.928792953491211
#
#
# Document: What is Kaufmich.com?
# Euclidean Distance : 14.939485549926758
#
#
# Document: What are the major differences betweeen SAP HANA and SAP R/3?
# Euclidean Distance : 14.940408706665039
#
#
# Document: How is Narendra Modi as a person?
# Euclidean Distance : 14.944291114807129
#
#
# Document: When was Quora launched?
# Euclidean Distance : 14.953001976013184
#
#
# Document: What breed is Odie from the Garfield comics?
# Euclidean Distance : 14.958846092224121
#
#
# Document: What are the specifications of the Acer Aspire E14?
# Euclidean Distance : 14.962943077087402
#
#
# Document: What is your review of Crystal IT?
# Euclidean Distance : 14.9673433303833
#
#
# Document: Can I get my provisional degree from MDU, Rohtak the same day? How much time does it take?
# Euclidean Distance : 14.97191333770752
#
#
# Document: Is there one god or many?
# Euclidean Distance : 14.972009658813477
#
#
# Document: I'm 18. What should I do?
# Euclidean Distance : 14.974753379821777
#
#
# Document: What are the castes that belong to the surname "Tharigopula"?
# Euclidean Distance : 14.97579574584961
#
#
# Document: In layman's terms, what does Palantir actually do?
# Euclidean Distance : 14.975879669189453
#
#
# Document: How is Physics Galaxy by Ashish Arora? Is it relevant for JEE?
# Euclidean Distance : 14.983543395996094
#
#
# Document: What words rhyme with "saying"?
# Euclidean Distance : 14.990800857543945
#
#
# Document: Does Reliance’s Jio 4G network work in Andaman and Nicobar islands, especially in its capital Port Blair?
# Euclidean Distance : 14.996153831481934
#
#
# Document: How do you say 1<x<2?
# Euclidean Distance : 14.9981689453125
#
#
# Document: What is the Hizmet movement?
# Euclidean Distance : 14.999102592468262
#
#
# Document: What is the significance of Box 5 in Phantom of the Opera?
# Euclidean Distance : 15.007901191711426
#
#
# Document: What is the main role of I?
# Euclidean Distance : 15.014192581176758
#
#
# Document: What was the significance of Severus Snape and Lily Potter having the same Patronus?
# Euclidean Distance : 15.014547348022461
#
#
# Document: How do I get bokeh effect on 50mm f1.8 when the sweet spot is f5.6?
# Euclidean Distance : 15.019953727722168
#
#
# Document: Human Behavior: What is the one lie that you tell yourself repeatedly?
# Euclidean Distance : 15.020780563354492
#
#
# Document: How do I research for MUN?
# Euclidean Distance : 15.028131484985352
#
#
# Document: What happened to ibeatyou.com?
# Euclidean Distance : 15.02945327758789
#
#
# Document: What happened to Tmartn?
# Euclidean Distance : 15.030978202819824
#
#
# Document: What do you get when you rearrange the letters LNGEDNA?
# Euclidean Distance : 15.038971900939941
#
#
# Document: Tinder - how do I delete my interests?
# Euclidean Distance : 15.039113998413086
#
#
# Document: What is the right name: Shawarma vs. Döner?
# Euclidean Distance : 15.040445327758789
#
#
# Document: What is rank at 550 marks in NEET 2016?
# Euclidean Distance : 15.040726661682129
#
#
# Document: What'd be the top (maximum) wavelength of an electromagnetic radiation to see a message written in a paper?
# Euclidean Distance : 15.042224884033203
#
#
# Document: What is the Mahabharata and Ramyana about?
# Euclidean Distance : 15.04546070098877
#
#
# Document: How is the procentual difference between 4% and 3%?
# Euclidean Distance : 15.046741485595703
#
#
# Document: What do the grade shares mean?
# Euclidean Distance : 15.048556327819824
#
#
# Document: Why is there no option to +1 Quora posts?
# Euclidean Distance : 15.052816390991211
#
#
# Document: What is the biggest lie you have ever told on Quora?
# Euclidean Distance : 15.06091594696045
#
#
# Document: Is Oculus done?
# Euclidean Distance : 15.061420440673828
#
#
# Document: Is Envita.com legit?
# Euclidean Distance : 15.067719459533691
#
#
# Document: What can one million dollars do?
# Euclidean Distance : 15.068119049072266
#
#
# Document: What are Elizabeth Warren's positions?
# Euclidean Distance : 15.072734832763672
#
#
# Document: What does tw4t mean?
# Euclidean Distance : 15.074444770812988
#
#
# Document: What does Adam D'Angelo think of Quora being addictive?
# Euclidean Distance : 15.076591491699219
#
#
# Document: What's the point of the joke about the horse pitching in Age of Adaline?
# Euclidean Distance : 15.078756332397461
#
#
# Document: What is the value of a 2 rupee note signed by Sri Venkitaramanan (1990-1992)?
# Euclidean Distance : 15.07984733581543
#
#
# Document: What do you think the cutoff of KVPY 2016 SA would be?
# Euclidean Distance : 15.081364631652832
#
#
# Document: What is the scope of growth in the ITIS in TCS?
# Euclidean Distance : 15.0836763381958
#
#
# Document: What are the differences between WeChat and QQ?
# Euclidean Distance : 15.089800834655762
#
#
# Document: Who is the most powerful character in Skyrim apart from Alduin?
# Euclidean Distance : 15.09108829498291
#
#
# Document: What was it like to work with Alan Greenspan?
# Euclidean Distance : 15.098791122436523
#
#
# Document: What are the differences between CSE and IT/ISE?
# Euclidean Distance : 15.103825569152832
#
#
# Document: What is the one thing that you would like to do if you had an unlimited amount of money?
# Euclidean Distance : 15.109341621398926
#
#
# Document: How do I convert NRE FD to RFC?
# Euclidean Distance : 15.115032196044922
#
#
# Document: How much time will spotify take to land in India?
# Euclidean Distance : 15.116141319274902
#
#
# Document: What is Ali Garh Trusteeship bill?
# Euclidean Distance : 15.121816635131836
#
#
# Document: Why is Kim Jung-Un so fat?
# Euclidean Distance : 15.121840476989746
#
#
# Document: Which are the famous caves in Chhattisgarh?
# Euclidean Distance : 15.123616218566895
#
#
# Document: How can I hack Clash of Clans for unlimited gems?
# Euclidean Distance : 15.126896858215332
#
#
# Document: Is Zee news a BJP owned channel?
# Euclidean Distance : 15.127824783325195
#
#
# Document: What is the greatest number that will divide 43, 91 and 183 so as to leave the same remainder in each case?
# Euclidean Distance : 15.131845474243164
#
#
# Document: What is the difference between lard and suet?
# Euclidean Distance : 15.132203102111816
#
#
# Document: How do Uber and Lyft compare in 2016?
# Euclidean Distance : 15.135384559631348
#
#
# Document: How did Leatherface (2017 movie) get greenlit? What's the backstory of how the movie got made?
# Euclidean Distance : 15.138242721557617
#
#
# Document: If w is brownian motion t is time, how dw^2=dt?
# Euclidean Distance : 15.139514923095703
#
#
# Document: What is Omoto.io?
# Euclidean Distance : 15.141582489013672
#
#
# Document: What is the significance of a 1962 American nickel?
# Euclidean Distance : 15.14613151550293
#
#
# Document: Who do you think will win IPL 2015?
# Euclidean Distance : 15.147016525268555
#
#
# Document: Should India change its name to Bharat/Hindustan?
# Euclidean Distance : 15.151490211486816
#
#
# Document: Would you switch from Canon 6D to Leica D-LUX 109?
# Euclidean Distance : 15.162307739257812
#
#
# Document: What is the limit of cos^2(1/(x^2)) as x->0?
# Euclidean Distance : 15.163003921508789
#
#
# Document: What is difference between immortality and eternity?
# Euclidean Distance : 15.16701889038086
#
#
# Document: Rastriya military school blore?
# Euclidean Distance : 15.176586151123047
#
#
# Document: What is the Heisenberg uncertainty priciple?
# Euclidean Distance : 15.177490234375
#
#
# Document: Is suzlon energy worth accumulating at this levels 17-18?
# Euclidean Distance : 15.18610954284668
#
#
# Document: What is the real meaning of the Indian flag Tiranga?
# Euclidean Distance : 15.189078330993652
#
#
# Document: Have you used Quora to find love?
# Euclidean Distance : 15.195879936218262
#
#
# Document: Want to know about Payoda (s/w company)?
# Euclidean Distance : 15.196459770202637
#
#
# Document: What is a "quasi-contract"? What are some examples?
# Euclidean Distance : 15.198770523071289
#
#
# Document: Is there any way to recover registration number of ICAI?
# Euclidean Distance : 15.199312210083008
#
#
# Document: How do I add images in Quora?
# Euclidean Distance : 15.201992988586426
#
#
# Document: Why would you use "if __name__ == '__main__'"?
# Euclidean Distance : 15.207975387573242
#
#
# Document: Which 2G Band (900/1800Mhz) was sold during 2G spectrum scam?
# Euclidean Distance : 15.20918083190918
#
#
# Document: How do you feel when someone upvotes your answer on Quora?
# Euclidean Distance : 15.212343215942383
#
#
# Document: What is the meaning of Urdu word 'Nasaaz'?
# Euclidean Distance : 15.216081619262695
#
#
# Document: What's the meaning of euthenesia?
# Euclidean Distance : 15.220586776733398
#
#
# Document: Why do you think you are special?
# Euclidean Distance : 15.230070114135742
#
#
# Document: Who is the PM of India?
# Euclidean Distance : 15.23029899597168
#
#
# Document: What were your experiences when you had roll no. 1?
# Euclidean Distance : 15.230727195739746
#
#
# Document: Will mhtcet engineering happen in 2017?
# Euclidean Distance : 15.242271423339844
#
#
# Document: What is the relation between yudhishthira and Shakuni?
# Euclidean Distance : 15.243878364562988
#
#
# Document: What is journalism for you?
# Euclidean Distance : 15.24466609954834
#
#
# Document: What is the purpose of double pulsing a thyristor?
# Euclidean Distance : 15.245502471923828
#
#
# Document: Where is travencore state in India?
# Euclidean Distance : 15.246386528015137
#
#
# Document: What are the major Development of Chhattisgarh?
# Euclidean Distance : 15.248858451843262
#
#
# Document: What are some gerunds examples?
# Euclidean Distance : 15.250716209411621
#
#
# Document: What is the creamy layer and the non-creamy layer in the OBC category?
# Euclidean Distance : 15.25501823425293
#
#
# Document: What do Quorans think of Balaji Viswanathan?
# Euclidean Distance : 15.256372451782227
#
#
# Document: What does Prof. Walter Lewin think about the movie Interstellar?
# Euclidean Distance : 15.25844955444336
#
#
# Document: Is IMS noida good for BCA?
# Euclidean Distance : 15.2656831741333
#
#
# Document: Why is Timbaland famous?
# Euclidean Distance : 15.267477989196777
#
#
# Document: How can one earn money on Quora?
# Euclidean Distance : 15.27282428741455
#
#
# Document: What is the most probable cutoff of KVPY SA 2016?
# Euclidean Distance : 15.27322006225586
#
#
# Document: If you were guaranteed the answer to one question, what would it be?
# Euclidean Distance : 15.2835054397583
#
#
# Document: I keep going back to the same place in my dream but the previous me is there already?
# Euclidean Distance : 15.285334587097168
#
#
# Document: How does one fall in love?
# Euclidean Distance : 15.28538703918457
#
#
# Document: How do I root an HTC Desire 826?
# Euclidean Distance : 15.287496566772461
#
#
# Document: Is wowchat legal in India?
# Euclidean Distance : 15.289285659790039
#
#
# Document: What is the relationship between E(1/x) and 1/E(x)?
# Euclidean Distance : 15.289703369140625
#
#
# Document: How do you know if you are in love with your crush?
# Euclidean Distance : 15.293251037597656
#
#
# Document: Which one is correct? “please let me know if you have any question” or ”please let me know if you have any questions”
# Euclidean Distance : 15.293601036071777
#
#
# Document: Is tattoo not allowed in IPS?
# Euclidean Distance : 15.29438304901123
#
#
# Document: How can I prove that (A × B) − (C × D) = (A − C) × B ∪ A × (B − D)?
# Euclidean Distance : 15.295811653137207
#
#
# Document: If you had 100 billion dollars and you knew that you would always live like a multi-billionaire, what would be the first thing that you would do with that money?
# Euclidean Distance : 15.296784400939941
#
#
# Document: How does one move from the UK to the US?
# Euclidean Distance : 15.299470901489258
#
#
# Document: Is hypnotism real? If yes, how does it work? Can you give a real life example?
# Euclidean Distance : 15.300040245056152
#
#
# Document: What is your take on Urjit Patel as the new RBI governor?
# Euclidean Distance : 15.302509307861328
#
#
# Document: Which is the best mechanics book for the JEE Advanced - BM Sharma (Cengage), D.C. Pandey (Arihant) or Anurag Mishra (Balaji)?
# Euclidean Distance : 15.306173324584961
#
#
# Document: How do I get Pikachu as my first Pokémon in Pokémon GO?
# Euclidean Distance : 15.312077522277832
#
#
# Document: What is my puk code?
# Euclidean Distance : 15.312310218811035
#
#
# Document: What is most embrassing moment of your life?
# Euclidean Distance : 15.31606388092041
#
#
# Document: What's the 'Theory Of Everything' you believe in?
# Euclidean Distance : 15.321648597717285
#
#
# Document: How is the word 'indolence' used in a sentence?
# Euclidean Distance : 15.325383186340332
#
#
# Document: The Pirate Bay: How can one lower their risk of being caught while continuing to torrent?
# Euclidean Distance : 15.328388214111328
#
#
# Document: How does the Laravel authentication work?
# Euclidean Distance : 15.3297700881958
#
#
# Document: What is it like to work at Prettysecrets.com?
# Euclidean Distance : 15.334650993347168
#
#
# Document: What is the temperament of a Lab/St. Bernard mix?
# Euclidean Distance : 15.339714050292969
#
#
# Document: What is activated complex?
# Euclidean Distance : 15.340104103088379
#
#
# Document: What is the name of the song in which picturized on Madhuri Dixit and Ranbir Kapoor and is from which movie?
# Euclidean Distance : 15.342445373535156
#
#
# Document: What part did the bureaucracy get to play in the run up to the recent demonetization move of GOI?
# Euclidean Distance : 15.345269203186035
#
#
# Document: Are sakaldiwipi brahmins from Egypt?
# Euclidean Distance : 15.345919609069824
#
#
# Document: How much is the maximum gold you can take when flying from India to USA?
# Euclidean Distance : 15.347999572753906
#
#
# Document: Why is editorial page of The Hindu so important for UPSC aspirants?
# Euclidean Distance : 15.348011016845703
#
#
# Document: What year did the letter J come?
# Euclidean Distance : 15.353768348693848
#
#
# Document: Could Snoke secretly be Darth Maul?
# Euclidean Distance : 15.353829383850098
#
#
# Document: How can I convert Right Ascension and declination of a galaxy to distances in parsecs or any other common form?
# Euclidean Distance : 15.35523509979248
#
#
# Document: How do I tackle AIIMS or neet physics?
# Euclidean Distance : 15.35711669921875
#
#
# Document: What are shot narrative paragraphs? What are some examples?
# Euclidean Distance : 15.357268333435059
#
#
# Document: What are the lyrics to "Vivre Sans Temps Mort" by Double Dagger?
# Euclidean Distance : 15.360864639282227
#
#
# Document: Can you edit an answer on Quora?
# Euclidean Distance : 15.361108779907227
#
#
# Document: How can one increase concentration?
# Euclidean Distance : 15.361913681030273
#
#
# Document: Is planet 9 real or a hype/joke like Nibiru?
# Euclidean Distance : 15.367079734802246
#
#
# Document: Is premarital sex ok?
# Euclidean Distance : 15.368608474731445
#
#
# Document: What are DOM charges in SBI?
# Euclidean Distance : 15.36877155303955
#
#
# Document: How can I find my epf number?
# Euclidean Distance : 15.369657516479492
#
#
# Document: Why is Arvind Kejriwal so obsessed with Modi?
# Euclidean Distance : 15.370564460754395
#
#
# Document: Why does Arvind Kejriwal always comment against Modi?
# Euclidean Distance : 15.371208190917969
#
#
# Document: Why does Quora limit my question details to 300 characters?
# Euclidean Distance : 15.371912956237793
#
#
# Document: What is it like inside a Poké Ball?
# Euclidean Distance : 15.374730110168457
#
#
# Document: Does Moto g4 plus heat?
# Euclidean Distance : 15.374922752380371
#
#
# Document: What's the difference between 4G and 4G LTE?
# Euclidean Distance : 15.3766508102417
#
#
# Document: What is the mitochondria? What is the main function?
# Euclidean Distance : 15.378838539123535
#
#
# Document: Do you know how many Gili islands are there in Lombok?
# Euclidean Distance : 15.379358291625977
#
#
# Document: Why do I have to join CEPT?
# Euclidean Distance : 15.381657600402832
#
#
# Document: Does PGDIRA provides placements?
# Euclidean Distance : 15.383463859558105
#
#
# Document: How is the word "capricious" used in a sentence?
# Euclidean Distance : 15.385468482971191
#
#
# Document: What is the difference between salary structure of RRB scale 1 and IBPS PO?
# Euclidean Distance : 15.389725685119629
#
#
# Document: What exactly are in-phase and out-of-phase in terms of waves?
# Euclidean Distance : 15.390761375427246
#
#
# Document: Is Stevie Wonder married?
# Euclidean Distance : 15.390897750854492
#
#
# Document: Why does Quora have a character limit for question titles and details?
# Euclidean Distance : 15.391398429870605
#
#
# Document: What's the difference between mi5 a?
# Euclidean Distance : 15.39180850982666
#
#
# Document: What are some of the biggest blunders in history?
# Euclidean Distance : 15.392104148864746
#
#
# Document: Why has not any Indian Mathematician won a Fields Medal?
# Euclidean Distance : 15.393041610717773
#
#
# Document: When do you upvote?
# Euclidean Distance : 15.394248008728027
#
#
# Document: Does freedom of speech extend to shouting?
# Euclidean Distance : 15.394827842712402
#
#
# Document: Between 6 new IIMs (Trichy, Ranchi and others), NITIE, DMS (IITD) and SJMSOM (IIT B) which one to choose in order of preference?
# Euclidean Distance : 15.395257949829102
#
#
# Document: What will the real estate look like now after the 500 and 1000 scraping?
# Euclidean Distance : 15.39717960357666
#
#
# Document: What are the origins of the Foochow or Fuzhou people?
# Euclidean Distance : 15.398488998413086
#
#
# Document: If you could go back in time and redo one thing, what would it be?
# Euclidean Distance : 15.40043830871582
#
#
# Document: If my reservation status is RAC, does it mean the seat has been confirmed?
# Euclidean Distance : 15.406431198120117
#
#
# Document: Is it possible to do CA after 12th Science?
# Euclidean Distance : 15.409809112548828
#
#
# Document: What is the PAN number of the Punjab National Bank (PNB)?
# Euclidean Distance : 15.416586875915527
#
#
# Document: Is there anyone who had bhild their own algorithm?
# Euclidean Distance : 15.416707038879395
#
#
# Document: What is difference between pkcs12 ,pkx and bks file?
# Euclidean Distance : 15.417016983032227
#
#
# Document: What is difference between Modi and Hitler?
# Euclidean Distance : 15.417625427246094
#
#
# Document: Can a Lightsaber cut through Adamantium?
# Euclidean Distance : 15.417874336242676
#
#
# Document: How would you summarize the purpose of life in one sentence?
# Euclidean Distance : 15.430585861206055
#
#
# Document: When is the next hearing on triple talaq case in supreme court India?
# Euclidean Distance : 15.43114948272705
#
#
# Document: Should you tip your Lyft driver?
# Euclidean Distance : 15.431962013244629
#
#
# Document: How do I set up my VPN?
# Euclidean Distance : 15.43466567993164
#
#
# Document: What does Noam Chomsky think of communism?
# Euclidean Distance : 15.439403533935547
#
#
# Document: What's harder at Stanford: CS 246 or 229?
# Euclidean Distance : 15.440239906311035
#
#
# Document: How is L&T Technology Services IPO?
# Euclidean Distance : 15.440873146057129
#
#
# Document: What was the significance of showing Amitabh Bachchan with a mask in the movie PINK?
# Euclidean Distance : 15.443120002746582
#
#
# Document: What is the difference between blood group O neg and O rh neg?
# Euclidean Distance : 15.44398307800293
#
#
# Document: What is the difference between Type A and Type B NFC?
# Euclidean Distance : 15.444073677062988
#
#
# Document: Were there any slave with the name Reddice?
# Euclidean Distance : 15.44440746307373
#
#
# Document: Did Ben Affleck shine more than Christian Bale as Batman?
# Euclidean Distance : 15.445342063903809
#
#
# Document: How can I promote Udemy course?
# Euclidean Distance : 15.446432113647461
#
#
# Document: Between Robert De Niro and Al Pacino, who is more successful?
# Euclidean Distance : 15.448518753051758
#
#
# Document: How do you make a heart picture collage on Pinterest?
# Euclidean Distance : 15.450389862060547
#
#
# Document: How can I stop dreaming so intensley?
# Euclidean Distance : 15.450660705566406
#
#
# Document: When will episode 103 of fairy tail 2014 come out?
# Euclidean Distance : 15.45595932006836
#
#
# Document: How did Lucifer and Gabrielle relate to each other?
# Euclidean Distance : 15.457094192504883
#
#
# Document: How can I just be myself?
# Euclidean Distance : 15.457704544067383
#
#
# Document: What is the song called in the background of this video?
# Euclidean Distance : 15.45980167388916
#
#
# Document: Cochin to London etihad is the change over time of 1hr sufficient in Dubai?
# Euclidean Distance : 15.45984172821045
#
#
# Document: Can I earn from Quora?
# Euclidean Distance : 15.461287498474121
#
#
# Document: How do I earn from Quora?
# Euclidean Distance : 15.461287498474121
#
#
# Document: How was it to meet Richard Feynman?
# Euclidean Distance : 15.467554092407227
#
#
# Document: Why did ceaser give the other apes a cookie?
# Euclidean Distance : 15.46870231628418
#
#
# Document: Is The Force Awakens the exact same plot as A New Hope?
# Euclidean Distance : 15.471297264099121
#
#
# Document: How can I be the top 1% of the world?
# Euclidean Distance : 15.472766876220703
#
#
# Document: Why does Dushka Zapata have a story about EVERYTHING? Are they all true?
# Euclidean Distance : 15.476181983947754
#
#
# Document: Why does Red keep the keys in OITNB?
# Euclidean Distance : 15.477240562438965
#
#
# Document: What is the meaning of the phrase "single and ready to mingle"?
# Euclidean Distance : 15.478289604187012
#
#
# Document: How do you type a facepalm in text?
# Euclidean Distance : 15.48109245300293
#
#
# Document: In comics Tony is one of the few who welds the infinity gauntlet should we expect him to do something like that in future infinity wars movie?
# Euclidean Distance : 15.486764907836914
#
#
# Document: IN WHAT Time will rs 3000 amounts to rs 5184 at compounded interest of 20%?
# Euclidean Distance : 15.487735748291016
#
#
# Document: Do Anybody know the cut off marks for ST in Assam CEE?
# Euclidean Distance : 15.488682746887207
#
#
# Document: How do you know you are ready to tell your significant other you love them?
# Euclidean Distance : 15.489053726196289
#
#
# Document: What color was Adam and Eve?
# Euclidean Distance : 15.489547729492188
#
#
# Document: Why did Malala Yousafzai win the Nobel Prize?
# Euclidean Distance : 15.490574836730957
#
#
# Document: A no divisible by both 3 and 14?
# Euclidean Distance : 15.490621566772461
#
#
# Document: What's the name of the song in this link below?
# Euclidean Distance : 15.493264198303223
#
#
# Document: How do I check the price for HP Elitebook 8440P?
# Euclidean Distance : 15.495375633239746
#
#
# Document: What is coplanar force?
# Euclidean Distance : 15.496431350708008
#
#
# Document: What is e-construction?
# Euclidean Distance : 15.499831199645996
#
#
# Document: What should I do to prepare for NDA?
# Euclidean Distance : 15.503486633300781
#
#
# Document: What are some sentence examples using "jejune"?
# Euclidean Distance : 15.503756523132324
#
#
# Document: What is the difference between U and U/A certified films?
# Euclidean Distance : 15.506217002868652
#
#
# Document: I got jio sim on 25th aug it is 4rth sep but still sim is not activated what I should do?
# Euclidean Distance : 15.507038116455078
#
#
# Document: Why does San Marino exist?
# Euclidean Distance : 15.507914543151855
#
#
# Document: What is the best crossover setting for subwoofer?
# Euclidean Distance : 15.51259994506836
#
#
# Document: What is Atal Pension Yojana? Who can join Atal Pension Yojana?
# Euclidean Distance : 15.512823104858398
#
#
# Document: How do I deal with a love triangle?
# Euclidean Distance : 15.513814926147461
#
#
# Document: In what sectors is it best to live in Gurgaon?
# Euclidean Distance : 15.514302253723145
#
#
# Document: What is 'Wants to share with you ' notification on fb?
# Euclidean Distance : 15.526586532592773
#
#
# Document: What is the evidence of King David's existence?
# Euclidean Distance : 15.526880264282227
#
#
# Document: Do I need a domicile certificate for NEET?
# Euclidean Distance : 15.526969909667969
#
#
# Document: What is the best way to round to the nearest integer?
# Euclidean Distance : 15.527230262756348
#
#
# Document: How do I read the ammeter of an Enfield?
# Euclidean Distance : 15.527528762817383
#
#
# Document: What are contact details of Michael Stevens of Vsauce?
# Euclidean Distance : 15.529609680175781
#
#
# Document: Did Mahabharata really happen?
# Euclidean Distance : 15.53145694732666
#
#
# Document: Can I do 2 diplomas simultaneously?
# Euclidean Distance : 15.536152839660645
#
#
# Document: How do I access Torbox in India?
# Euclidean Distance : 15.536555290222168
#
#
# Document: Given that alpha and beta are roots of the equation 3x^2-5=0 form the equation whose roots are 2alpha-1/beta, 2alpha-/alpha?
# Euclidean Distance : 15.536914825439453
#
#
# Document: What is the best ux resume?
# Euclidean Distance : 15.541847229003906
#
#
# Document: Will the novel ever die?
# Euclidean Distance : 15.544923782348633
#
#
# Document: Quora: How do you post a question on Quora?
# Euclidean Distance : 15.547515869140625
# Document: How do I post a question in Quora?
# Euclidean Distance : 15.55161190032959
#
#
# Document: How do you post a question on Quora?
# Euclidean Distance : 15.55161190032959
#
#
# Document: What should be the first question to ask on Quora?
# Euclidean Distance : 15.555811882019043
#
#
# Document: Does it matter where I do my masters?
# Euclidean Distance : 15.559514045715332
#
#
# Document: Which manga is better: Hunter x Hunter or One Piece?
# Euclidean Distance : 15.559744834899902
#
#
# Document: What does litmus paper do and how is it made?
# Euclidean Distance : 15.560842514038086
#
#
# Document: What would it look like here on earth if your sun was a Pulsar?
# Euclidean Distance : 15.562704086303711
#
#
# Document: Have you ever been fired?
# Euclidean Distance : 15.566394805908203
#
#
# Document: Have you ever taken revenge? How and why did you take it?
# Euclidean Distance : 15.569156646728516
#
#
# Document: What are the greatest comebacks in history?
# Euclidean Distance : 15.571942329406738
#
#
# Document: What is the use of getting more upvotes in Quora?
# Euclidean Distance : 15.572210311889648
#
#
# Document: How can I install Bluestacks in Ubuntu?
# Euclidean Distance : 15.575922012329102
#
#
# Document: Which were some of the most amazing responses you have got with Cortana, Siri or Amazon Echo?
# Euclidean Distance : 15.577696800231934
#
#
# Document: What are examples of a pun?
# Euclidean Distance : 15.578010559082031
#
#
# Document: What's the deepest cut you can get with a table saw?
# Euclidean Distance : 15.578510284423828
#
#
# Document: What is that one story or incident that truly depicts the spirit of Delhi?
# Euclidean Distance : 15.581218719482422
#
#
# Document: What is the meaning of Hindi/Urdu word 'Shiksha' and 'Taleem'?
# Euclidean Distance : 15.583352088928223
#
#
# Document: What are the best tweets by virender Sehwag?
# Euclidean Distance : 15.589217185974121
#
#
# Document: Can anybody help me with Compare and contrast Haroun and Rashid character from story Haroun and the Sea of stories?
# Euclidean Distance : 15.589469909667969
#
#
# Document: Game of Thrones Season 6 Episode 4: What did the High Sparrow tell Tommen in secret that he repeated to Cersei?
# Euclidean Distance : 15.59049129486084
#
#
# Document: What is one sided love for you?
# Euclidean Distance : 15.590710639953613
#
#
# Document: How long will the reservation system (quota) continue in India?
# Euclidean Distance : 15.594395637512207
#
#
# Document: How is the word 'ubiquitous' used in a sentence?
# Euclidean Distance : 15.594660758972168
#
#
# Document: How you say lover in Hindi?
# Euclidean Distance : 15.598511695861816
#
#
# Document: How should I start writing on Quora?
# Euclidean Distance : 15.599355697631836
#
#
# Document: What is the greatest mystery of all time?
# Euclidean Distance : 15.604230880737305
#
#
# Document: How hard was it for Jimmy Wales to immigrate to the UK?
# Euclidean Distance : 15.606654167175293
#
#
# Document: Who invented light years?
# Euclidean Distance : 15.607782363891602
#
#
# Document: What is the use of nested loops?
# Euclidean Distance : 15.61202621459961
#
#
# Document: How do you find the [math]\frac{dy}{dx}[/math] of [math]\tan\left(\frac{x}{y}\right) =x+y[/math]?
# Euclidean Distance : 15.620708465576172
#
#
# Document: How does the rest of the world see Republicans?
# Euclidean Distance : 15.621703147888184
#
#
# Document: What is the difference between bay, gulf and straits?
# Euclidean Distance : 15.622167587280273
#
#
# Document: What is the set up and hold time violations in VLSI?
# Euclidean Distance : 15.624805450439453
#
#
# Document: What does the nuclear membrane do?
# Euclidean Distance : 15.626566886901855
#
#
# Document: What are the 7 strongest hokages?
# Euclidean Distance : 15.627604484558105
#
#
# Document: How is telling a non-Christian they are going to hell an expression of love?
# Euclidean Distance : 15.628912925720215
#
#
# Document: Irrespective of cost which parker fountain pen is the best in looks and writing?
# Euclidean Distance : 15.628941535949707
#
#
# Document: How can I meet Narendra Modi?
# Euclidean Distance : 15.629923820495605
#
#
# Document: When will Redmi Note 3 be available on Flipkart and Snapdeal?
# Euclidean Distance : 15.630349159240723
#
#
# Document: What is qiymat.com?
# Euclidean Distance : 15.63093090057373
#
#
# Document: What do belly button piercings feel like?
# Euclidean Distance : 15.634306907653809
#
#
# Document: What's the difference between LR6 and AA batteries?
# Euclidean Distance : 15.635554313659668
#
#
# Document: What are Bulova watches like?
# Euclidean Distance : 15.636539459228516
#
#
# Document: How much is 30 kV in HP?
# Euclidean Distance : 15.636959075927734
#
#
# Document: What are some Cyanide and Happiness comics on countries?
# Euclidean Distance : 15.638448715209961
#
#
# Document: What is backend process?
# Euclidean Distance : 15.638683319091797
#
#
# Document: How do I know if he is even a crush?
# Euclidean Distance : 15.6408109664917
#
#
# Document: What are some synonyms for "results-oriented"?
# Euclidean Distance : 15.642282485961914
#
#
# Document: What is the GST?
# Euclidean Distance : 15.646707534790039
#
#
# Document: What is that 80's song that has a chorus of "woah oh oh oh"?
# Euclidean Distance : 15.647241592407227
#
#
# Document: What is the most interesting shell script you have ever written?
# Euclidean Distance : 15.649737358093262
#
#
# Document: What should I know to get into GSoC?
# Euclidean Distance : 15.65139102935791
#
#
# Document: Eb-2 Visa: Just got married! My husband's EB2 application has just been approved. Can he include me as his derivative and ammend his records in USCIS?
# Euclidean Distance : 15.65189266204834
#
#
# Document: Is God really present?
# Euclidean Distance : 15.652092933654785
#
#
# Document: How do you know you have a crush?
# Euclidean Distance : 15.655488014221191
#
#
# Document: What should I double major with foreign language?
# Euclidean Distance : 15.657919883728027
#
#
# Document: What is Shah Rukh Khan doing now?
# Euclidean Distance : 15.663381576538086
#
#
# Document: How do you delete a question you asked on Quora
# Euclidean Distance : 15.668769836425781
#
#
# Document: What is Harvey and Donna's pre-trial secret ritual in Suits?
# Euclidean Distance : 15.66995620727539
#
#
# Document: Why do we use chi-square test?
# Euclidean Distance : 15.67137336730957
#
#
# Document: Is coaching necessary to crack JEE Advanced?
# Euclidean Distance : 15.672840118408203
#
#
# Document: What are the best branches at NIT Jamshedpur?
# Euclidean Distance : 15.673357009887695
#
#
# Document: How does one score good marks in MAKAUT?
# Euclidean Distance : 15.67536449432373
#
#
# Document: Is Quora a hit or a miss?
# Euclidean Distance : 15.676259994506836
#
#
# Document: What is a Crush Card in "Yu-Gi-Oh!"?
# Euclidean Distance : 15.677289962768555
#
#
# Document: What is the summary of Malcolm X's speech "Ballot or the Bullet"?
# Euclidean Distance : 15.67900562286377
#
#
# Document: Is the soul immortal?
# Euclidean Distance : 15.68126106262207
#
#
# Document: What's a cornerstone investor?
# Euclidean Distance : 15.681615829467773
#
#
# Document: What do you make of this Game of Thrones theory?
# Euclidean Distance : 15.684277534484863
#
#
# Document: What is the percentage of placements in the college of SSIPMT (Shri Shankracharya College of Engineering, Raipur)?
# Euclidean Distance : 15.690019607543945
#
#
# Document: How is cleavaland state university for MS IN CS?
# Euclidean Distance : 15.690730094909668
#
#
# Document: What are the chances of ww3?
# Euclidean Distance : 15.69201374053955
#
#
# Document: What is the difference between O- and O+?
# Euclidean Distance : 15.696833610534668
#
#
# Document: How can I apply pan card with initial in surname or last name for reprinting my pan card?
# Euclidean Distance : 15.699847221374512
#
#
# Document: Why is my period 11 days late and how probable is it that I'm pregnant?
# Euclidean Distance : 15.703550338745117
#
#
# Document: What are your favorite prophecies in ASOIAF/Game of Thrones?
# Euclidean Distance : 15.703691482543945
#
#
# Document: What should I do to become a top writer on Quora?
# Euclidean Distance : 15.703702926635742
#
#
# Document: What's the first word that comes to your mind when you hear "Quora"?
# Euclidean Distance : 15.709148406982422
#
#
# Document: What is the life of ies?
# Euclidean Distance : 15.709339141845703
#
#
# Document: What is the moral of Leo Tolstoy's short story "Alyosha the Pot"?
# Euclidean Distance : 15.709903717041016
#
#
# Document: How much does Hanes charge for shipping?
# ...
# Euclidean Distance : 21.01791763305664
#
#
# Document: Which option is better to reduce weight, swimming or gym?
# Euclidean Distance : 21.03554344177246
#
#
# Document: What is the difference between a turkey and a chicken?
# Euclidean Distance : 21.044313430786133
#
#
# Document: Is yoga really beneficial for everyone?
# Euclidean Distance : 21.04935646057129
#
#
# Document: Why do poor people deserve welfare benefits?
# Euclidean Distance : 21.050342559814453
#
#
# Document: Which social network drives the most traffic?
# Euclidean Distance : 21.051389694213867
#
#
# Document: Do wasps sting people?
# Euclidean Distance : 21.069311141967773
#
#
# Document: What can I eat every day to be more healthy?
# Euclidean Distance : 21.080060958862305
#
#
# Document: How much time does a waiter spend in taking orders?
# Euclidean Distance : 21.08468246459961
#
#
# Document: Why is my dog throwing up yellow bile? What should I do to help him?
# Euclidean Distance : 21.08486557006836
#
#
# Document: When do most people shop online?
# Euclidean Distance : 21.085847854614258
#
#
# Document: I a male and not gay my friend took me to a Pakistani gay bar my drink must have been drugged, when I woke up I was naked what will they do to me?
# Euclidean Distance : 21.094614028930664
#
#
# Document: Why are people who are not vegan so vehement in criticizing vegans who live with vegan dogs?
# Euclidean Distance : 21.095361709594727
#
#
# Document: How can medical doctors move into biotech or molecular biology?
# Euclidean Distance : 21.10061264038086
#
#
# Document: Why do girls hate funny guys?
# Euclidean Distance : 21.110620498657227
#
#
# Document: How do I improve diet to gain weight? What are other options to gain weight?
# Euclidean Distance : 21.11113929748535
#
#
# Document: I want to meet an introverted man, where should I go? I hate bars/clubs and know I would never meet the person I want to be with there.
# Euclidean Distance : 21.112903594970703
#
#
# Document: Which is less healthy for your body, beer or Pepsi?
# Euclidean Distance : 21.11405372619629
#
#
# Document: Can being bullied or having less sleep cause social anxiety?
# Euclidean Distance : 21.124059677124023
#
#
# Document: How do buffalo meat and cow beef differ?
# Euclidean Distance : 21.129331588745117
#
#
# Document: Are most blind people completely blind?
# Euclidean Distance : 21.130264282226562
#
#
# Document: How can I get the Calendar Mac app from automatically sending me email notifications in my preferences?
# Euclidean Distance : 21.13996124267578
#
#
# Document: How would you order these four cities (Bangalore, Chennai, Hyderabad, Pune) for living (considering climate, people, food, future growth, safety, cost of living, etc.)?
# Euclidean Distance : 21.141157150268555
#
#
# Document: What is your favorite salad recipe?
# Euclidean Distance : 21.145042419433594
#
#
# Document: How do you cook bacon without an oven or microwave?
# Euclidean Distance : 21.157791137695312
#
#
# Document: What are some online resources to learn UI design?
# Euclidean Distance : 21.158212661743164
#
#
# Document: Why is reducing individual and societal ecological footprint necessary and important?
# Euclidean Distance : 21.171112060546875
#
#
# Document: What is my strategy for applying for Economics graduate school no research/internships?
# Euclidean Distance : 21.171632766723633
#
#
# Document: How can I raise money for a social startup?
# Euclidean Distance : 21.179080963134766
#
#
# Document: How do I start a grocery shop online?
# Euclidean Distance : 21.179962158203125
#
#
# Document: SOS: I forgot to take the piece of tissue paper out of my trousers' pocket before washing them with my other clothes in my washing machine. Now all my washed clothes are full with residue of that piece of tissue paper. What's the best solution to solve this problem?
# Euclidean Distance : 21.18084144592285
#
#
# Document: How can I promote my business in Twitter?
# Euclidean Distance : 21.18320655822754
#
#
# Document: How widely accepted are credit cards at small businesses and restaurants in Brazil?
# Euclidean Distance : 21.188634872436523
#
#
# Document: What is a good substitute for milk in macaroni and cheese?
# Euclidean Distance : 21.188888549804688
#
#
# Document: Mountain Climbing: Can anyone climb Mount Everest?
# Euclidean Distance : 21.191204071044922
#
#
# Document: How do you wash boots in a washing machine?
# Euclidean Distance : 21.200407028198242
#
#
# Document: How would astronauts navigate on the moon?
# Euclidean Distance : 21.20160484313965
#
#
# Document: How long does a routine dental checkup normally take in the U.S., if the patient is perfectly healthy and schedules one every six months?
# Euclidean Distance : 21.214399337768555
#
#
# Document: What is served for breakfast on a typical US army base?
# Euclidean Distance : 21.21561050415039
#
#
# Document: Why do fashion designers create weird clothes that they don't sell at shops?
# Euclidean Distance : 21.216968536376953
#
#
# Document: Who are some children who murdered their parents?
# Euclidean Distance : 21.223812103271484
#
#
# Document: How much water should a normal, healthy adult drink on a daily basis to avoid dehydration?
# Euclidean Distance : 21.226652145385742
#
#
# Document: Does green tea really reduces weight?
# Euclidean Distance : 21.22975730895996
#
#
# Document: What skills should I learn before searching a software developer job in Java or Web Development?
# Euclidean Distance : 21.235334396362305
#
#
# Document: In which countries can dogs travel on public transportation without a muzzle?
# Euclidean Distance : 21.241207122802734
#
#
# Document: Are cats afraid of tigers?
# Euclidean Distance : 21.25075912475586
#
#
# Document: Which institutions in Kolkata give coaching for entrance exams for a master's in political science?
# Euclidean Distance : 21.255992889404297
#
#
# Document: What kind of doctor should I go to that treats mental health problems with diet, supplements, etc?
# Euclidean Distance : 21.256364822387695
#
#
# Document: How can I ask a supermarket owner to put an advertisement photo of my new product in the supermarket entrance?
# Euclidean Distance : 21.259790420532227
#
#
# Document: Is there a way to get a user's friends' email address through Facebook API for php?
# Euclidean Distance : 21.26310920715332
#
#
# Document: Can hamsters eat apples?
# Euclidean Distance : 21.263328552246094
#
#
# Document: How can I learn to play the piano/synthesizer?
# Euclidean Distance : 21.268423080444336
#
#
# Document: What are some good tips while learning piano?
# Euclidean Distance : 21.281845092773438
#
#
# Document: Are there People who are willing to give free lectures or conduct free workshop in India colleges?
# Euclidean Distance : 21.283262252807617
#
#
# Document: Can kittens eat watermelon? If not, why?
# Euclidean Distance : 21.288515090942383
#
#
# Document: How can I help or encourage my mother to lose weight?
# Euclidean Distance : 21.297414779663086
#
#
# Document: Is it ok to feed asparagus to dogs?
# Euclidean Distance : 21.297649383544922
#
#
# Document: How does the tap water distribution and sewage disposal system work in Kolkata?
# Euclidean Distance : 21.299768447875977
#
#
# Document: How do we avoid whey in Yogurt?
# Euclidean Distance : 21.302289962768555
#
#
# Document: Why do some of my black friends hate white people?
# Euclidean Distance : 21.30338478088379
#
#
# Document: What is it like at the University of Chicago? How are the students and the professors?
# Euclidean Distance : 21.3043155670166
#
#
# Document: Does green tea really help in losing weight?
# Euclidean Distance : 21.310901641845703
#
#
# Document: What foods can help boost creativity?
# Euclidean Distance : 21.32776641845703
#
#
# Document: Do cops really check the license plate of the car in front of them?
# Euclidean Distance : 21.328136444091797
#
#
# Document: What are some examples of animals that eat both plants and animals?
# Euclidean Distance : 21.328378677368164
#
#
# Document: When renting a car, what is the difference between a compact and economy car?
# Euclidean Distance : 21.33390235900879
#
#
# Document: What can a man do if a woman rapes him?
# Euclidean Distance : 21.3346004486084
#
#
# Document: Carolina Panthers Live Streaming | Watch Carolina Panthers Live Stream NFL Games Today Online?
# Euclidean Distance : 21.337932586669922
#
#
# Document: How are people you are not friends with on Facebook be in your favorites?
# Euclidean Distance : 21.352033615112305
#
#
# Document: How do Boeing and Airbus deliver airplanes to buyers?
# Euclidean Distance : 21.352632522583008
#
#
# Document: I'm a big guy. When I get angry, people get scared and accuse me of threatening them. How do I stop this? I'm not actually a violent person.
# Euclidean Distance : 21.370088577270508
#
#
# Document: When wild humans are found in the wild, why are people using the word "rescue" from his/her animal families when they're actually kidnapping him/her?
# Euclidean Distance : 21.374038696289062
#
#
# Document: What are good gifts for a foreign visitor to bring when they're invited to someone's home in Turkey for the first time?
# Euclidean Distance : 21.38355827331543
#
#
# Document: How do I survive the competition in online food ordering (middleman) business?
# Euclidean Distance : 21.3972110748291
#
#
# Document: Why do oil heaters (room heaters) have fans. Do they burn oxygen, too?
# Euclidean Distance : 21.399612426757812
#
#
# Document: Why do joggers early in the morning and in the evening wear dark clothes and run in the streets without a flashlight, even when there are sidewalks?
# Euclidean Distance : 21.401905059814453
#
#
# Document: Why do some dogs like to eat poo?
# Euclidean Distance : 21.417999267578125
#
#
# Document: My family doesn't respect my contribution to chores, office work. They talk disrespectfully & get verbally aggressive. What to do.?
# Euclidean Distance : 21.430274963378906
#
#
# Document: What do astronauts aboard ISS do when a solar storm is headed there way?
# Euclidean Distance : 21.438051223754883
#
#
# Document: Is it healthy to eat one chicken every day?
# Euclidean Distance : 21.438520431518555
#
#
# Document: How can you use dish soap in a dishwasher?
# Euclidean Distance : 21.445470809936523
#
#
# Document: I have seen porn stars lick the asshole of the partner they will be doing. Isn't that disgusting? How do you eat food afterwards?
# Euclidean Distance : 21.449569702148438
#
#
# Document: Can you feed pork rib bones to dogs?
# Euclidean Distance : 21.466405868530273
#
#
# Document: What side dishes go well with hamburgers?
# Euclidean Distance : 21.46673011779785
#
#
# Document: How do I learn strumming on a guitar?
# Euclidean Distance : 21.46727752685547
#
#
# Document: What are your favorite Chinese foods?
# Euclidean Distance : 21.477895736694336
#
#
# Document: Can we charge laptops via USB with a power bank?
# Euclidean Distance : 21.478370666503906
#
#
# Document: Will I lose weight by only drinking water?
# Euclidean Distance : 21.48185920715332
#
#
# Document: How do I learn to play soccer?
# Euclidean Distance : 21.492708206176758
#
#
# Document: What is the best dry dog food brand for picky eaters?
# Euclidean Distance : 21.502239227294922
#
#
# Document: Which is better: reading manga or watching anime?
# Euclidean Distance : 21.50657081604004
#
#
# Document: Is there a special dish/food from your home country that your family has incorporated into the traditional American Thanksgiving meal?
# Euclidean Distance : 21.511123657226562
#
#
# Document: How do I promote my custom-made wooden furniture manufacturing business?
# Euclidean Distance : 21.514039993286133
#
#
# Document: Can I feed my dog asparagus? Is it harmful for him?
# Euclidean Distance : 21.514667510986328
#
#
# Document: What are the qualifications of professional food tasters?
# Euclidean Distance : 21.51944351196289
#
#
# Document: Which pizzas are the most popularly ordered pizzas on Domino's menu?
# Euclidean Distance : 21.52318000793457
#
#
# Document: What Quora user would you most like to have lunch with?
# Euclidean Distance : 21.53302574157715
#
#
# Document: How do I learn some simple, practical ways of doing meditation?
# Euclidean Distance : 21.534854888916016
#
#
# Document: Do other cars taunt you while you are driving in public?
# Euclidean Distance : 21.54184913635254
#
#
# Document: My dog can't really move after his bath. What do I do?
# Euclidean Distance : 21.549396514892578
#
#
# Document: Do cricket players really drink tea on a tea break?
# Euclidean Distance : 21.554637908935547
#
#
# Document: Why do some people bully others? Why some of them have pleasure on bullying others?
# Euclidean Distance : 21.59278678894043
#
#
# Document: Can dogs eat grape jelly? Why or why not?
# Euclidean Distance : 21.6141414642334
#
#
# Document: How should a teacher maintain discipline in the classroom?
# Euclidean Distance : 21.615676879882812
#
#
# Document: How do I learn acoustic guitar at home?
# Euclidean Distance : 21.61730194091797
#
#
# Document: How can Google Analytics data and machine learning help an online business?
# Euclidean Distance : 21.620357513427734
#
#
# Document: How do I get driving license in India for driving Volvo air bus, lorry and truck? Where can I learn driving bus, lorry and truck in Chennai?
# Euclidean Distance : 21.623689651489258
#
#
# Document: Where can I learn about reading and understanding the log files in my Mac's Console?
# Euclidean Distance : 21.624975204467773
#
#
# Document: How do you make fresh lemonade?
# Euclidean Distance : 21.640413284301758
#
#
# Document: How do pilots avoid turbulence?
# Euclidean Distance : 21.660282135009766
#
#
# Document: A couple who has 5 sons went for a picnic. Each son has 7 sisters. Each sister has 3 babies. In total, how many people went for the picnic?
# Euclidean Distance : 21.672574996948242
#
#
# Document: What does it mean if a dog vomits white foam?
# Euclidean Distance : 21.67441749572754
#
#
# Document: Are there any universities that teach film production to people who have no filmmaking experience?
# Euclidean Distance : 21.695829391479492
#
#
# Document: How is the restaurant business?
# Euclidean Distance : 21.70648956298828
#
#
# Document: Which one of this is correct: I had my lunch, I have had my lunch, I have ate my lunch?
# Euclidean Distance : 21.74577522277832
#
#
# Document: How do I learn about computer programming, networking and computer hardware?
# Euclidean Distance : 21.776914596557617
#
#
# Document: How can I learn how to play the piano?
# Euclidean Distance : 21.840396881103516
#
#
# Document: Is drinking milk good if I am aiming for fat loss by maintaining a low calorie diet? Also is it advisable to drink milk before a workout?
# Euclidean Distance : 21.843660354614258
#
#
# Document: Is organic food really healthier? Is it more nutritious?
# Euclidean Distance : 21.8501033782959
#
#
# Document: Should the toothbrush be wet or dry before applying the toothpaste?
# Euclidean Distance : 21.866880416870117
#
#
# Document: What same food should I eat every day to protect my health?
# Euclidean Distance : 21.878192901611328
#
#
# Document: How can I make a healthy home made pizza?
# Euclidean Distance : 21.881532669067383
#
#
# Document: If I skip breakfast and lunch, and only have dinner and two cups of coffee in a whole day, will I lose weight?
# Euclidean Distance : 21.93378257751465
#
#
# Document: How cosmonauts/astronauts are located inside Soyuz spacecraft?
# Euclidean Distance : 21.940162658691406
#
#
# Document: When a police officer pulls you over and you drive into your own driveway, what will the police do?
# Euclidean Distance : 22.018335342407227
#
#
# Document: Why are there no healthy fast food restaurants?
# Euclidean Distance : 22.058021545410156
#
#
# Document: If a tow truck is about to tow your car, can you get in the car and refuse to have it towed?
# Euclidean Distance : 22.073081970214844
#
#
# Document: If a guy asks a girl out to dinner, when is it a date and when is it not a date?
# Euclidean Distance : 22.11357879638672
#
#
# Document: Three upperclassmen at my school jokingly pull their pants all the way down when urinating. How can I properly express my disgust?
# Euclidean Distance : 22.152393341064453
#
#
# Document: Will eating large amounts of yogurt make me sick?
# Euclidean Distance : 22.170949935913086
#
#
# Document: Can we eat meat with dairy products?
# Euclidean Distance : 22.37159538269043
#
#
# Document: Do vegetarians feed their dogs with meat?
# Euclidean Distance : 22.91551971435547
